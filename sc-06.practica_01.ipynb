// %% [markdown]
// ## Ejercicio 1 — val y var

// %%
// val: describe el curso (no cambia durante la ejecución)
val nombreCurso = "Big Data con Scala"
val numeroDias  = 28
val horasPorDia = 5.0

println(s"Curso: $nombreCurso")
println(s"Duración: $numeroDias días × $horasPorDia h/día = ${numeroDias * horasPorDia} horas")
// Out:
// Curso: Big Data con Scala
// Duración: 28 días × 5.0 h/día = 140.0 horas
// nombreCurso: String = "Big Data con Scala"
// numeroDias: Int = 28
// horasPorDia: Double = 5.0

// %%
// var: el contador de sesiones cambia a lo largo del programa
var sesionesCompletadas = 0
println(s"Sesiones completadas al inicio: $sesionesCompletadas")

sesionesCompletadas = sesionesCompletadas + 1
println(s"Después de la Sesión 1: $sesionesCompletadas")

sesionesCompletadas += 1
println(s"Después de la Sesión 2: $sesionesCompletadas")
// Out:
// Sesiones completadas al inicio: 0
// Después de la Sesión 1: 1
// Después de la Sesión 2: 2
// sesionesCompletadas: Int = 2

// %%
// Descomenta la siguiente línea para ver el error de compilación:
// numeroDias = 30
// error: reassignment to val

// %% [markdown]
// ### Preguntas de reflexión
// 1. ¿Por qué `nombreCurso` y `numeroDias` son `val` y no `var`?
// Son constantes, no se pueden modificar
// 2. ¿Por qué `sesionesCompletadas` es `var`?
// es variable, se puede modificar
// 3. ¿Qué mensaje de error aparece si intentas reasignar un `val`?

// %% [markdown]
// ## Ejercicio 2 — Calculadora básica

// %%
val a: Double = 15.0
val b: Double = 4.0

val suma     = a + b
val resta    = a - b
val producto = a * b
val division = a / b
val modulo   = a % b

println("=== Calculadora Scala ===")
println(f"  $a%.1f + $b%.1f = $suma%.1f")
println(f"  $a%.1f - $b%.1f = $resta%.1f")
println(f"  $a%.1f × $b%.1f = $producto%.1f")
println(f"  $a%.1f ÷ $b%.1f = $division%.4f")
println(f"  $a%.1f %% $b%.1f = $modulo%.1f")
// Out:
// === Calculadora Scala ===
//   15.0 + 4.0 = 19.0
//   15.0 - 4.0 = 11.0
//   15.0 × 4.0 = 60.0
//   15.0 ÷ 4.0 = 3.7500
//   15.0 % 4.0 = 3.0
// a: Double = 15.0
// b: Double = 4.0
// suma: Double = 19.0
// resta: Double = 11.0
// producto: Double = 60.0
// division: Double = 3.75
// modulo: Double = 3.0

// %%
println("=== División entera con Int===")
val x: Int = 15
val y: Int = 4

println(s"División entera: $x / $y = ${x / y}")
println(s"Resto:           $x % $y = ${x % y}")

print("=== Comparaciones ===")
println(s"\n¿$a > $b?   ${a > b}")
println(s"¿$a == $b?  ${a == b}")
println(s"¿$a != $b?  ${a != b}")
// Out:
// === División entera con Int===
// División entera: 15 / 4 = 3
// Resto:           15 % 4 = 3
// === Comparaciones ===
// ¿15.0 > 4.0?   true
// ¿15.0 == 4.0?  false
// ¿15.0 != 4.0?  true
// x: Int = 15
// y: Int = 4

// %%
val pesoKg    = 90.0
val alturaMts = 1.80

val imc = pesoKg / (alturaMts * alturaMts)

val categoria =
  if      (imc < 18.5) "Bajo peso"
  else if (imc < 25.0) "Normal"
  else if (imc < 30.0) "Sobrepeso"
  else                 "Obesidad"

println(f"IMC: $imc%.2f → $categoria")
// Out:
// IMC: 27.78 → Sobrepeso
// pesoKg: Double = 90.0
// alturaMts: Double = 1.8
// imc: Double = 27.777777777777775
// categoria: String = "Sobrepeso"

// %% [markdown]
// ## Ejercicio 3 — Interpolación de strings

// %%
val nombre       = "Javier Martinez"
val edad         = 53
val nota         = 8.756
val aprobado     = nota >= 5.0
val rutaInformes = raw"C:\Informes\Alumnos\2026"

// Interpolador s
println(s"Alumno: $nombre")
println(s"Edad:   $edad años")
println(s"¿Ha aprobado? $aprobado")
println(s"Años hasta jubilación (65): ${65 - edad}")
// Out:
// Alumno: Javier Martinez
// Edad:   53 años
// ¿Ha aprobado? true
// Años hasta jubilación (65): 12
// nombre: String = "Javier Martinez"
// edad: Int = 53
// nota: Double = 8.756
// aprobado: Boolean = true
// rutaInformes: String = "C:\\Informes\\Alumnos\\2026"

// %%
// Interpolador f: formato decimal
println(f"Nota final:    $nota%.2f")
println(f"Nota sobre 10: $nota%05.2f")

// Interpolador raw: ruta Windows sin problemas con \
println(s"\nRuta de informes: $rutaInformes")
// Out:
// Nota final:    8.76
// Nota sobre 10: 08.76
//
// Ruta de informes: C:\Informes\Alumnos\2026

// %% [markdown]
// ---
// ### Ejercicio P1 — Ficha personal
// Declara las siguientes variables con el tipo adecuado e imprime una ficha con interpolador `s`:
//
// - Tu nombre (texto)
// - Tu edad (entero)
// - Tu altura en metros (decimal)
// - Si estás trabajando actualmente (booleano)
//
// **Salida esperada** (con tus datos):
//
// ```
// === Ficha Personal ===
// Nombre:   Laura Martínez
// Edad:     35 años
// Altura:   1.68 m
// Trabajando: true
// ```

// %%
val nombre       = "Javier Martinez"
val edad         = 53
val altura       = 1.80
val trabajando   = false


println("=== Ficha Personal")
println(s"Alumno: $nombre")
println(s"Edad:   $edad años")
println(f"Altura: $altura%.2f m")
println(s"Trabajando: $trabajando")
// Out:
// === Ficha Personal
// Alumno: Javier Martinez
// Edad:   53 años
// Altura: 1.80 m
// Trabajando: false
// nombre: String = "Javier Martinez"
// edad: Int = 53
// altura: Double = 1.8
// trabajando: Boolean = false

// %% [markdown]
// ### Ejercicio P2 — Conversor de minutos
// Declara una variable `minutosTotales` con el valor `137`. Calcula y muestra cuántas horas y minutos son usando división entera y el operador módulo `%`.

// %%
val minutosTotales = 137

val horas    = minutosTotales / 60
val minutos  = minutosTotales % 60

println("=== Calculadora Scala ===")
println(s"  $minutosTotales minutos = $horas horas y $minutos minutos")
// Out:
// === Calculadora Scala ===
//   137 minutos = 2 horas y 17 minutos
// minutosTotales: Int = 137
// horas: Int = 2
// minutos: Int = 17

// %% [markdown]
// ### Ejercicio P3 — Comparador de precios
//
// Declara dos precios: `precioA = 49.99` y `precioB = 67.50`. Usando operadores de comparación, imprime:
//
// **Salida esperada:**
//
// ```
// ¿precioA es menor que precioB?   true
// ¿Son iguales?                    false
// ¿precioA es mayor o igual?       false
// La diferencia es: 17.51 €
// ```

// %%
val precioA = 49.99
val precioB = 67.50

println(s"¿precioA es menor que precioB?   ${precioA < precioB}") //true
println(s"¿Son iguales?                    ${precioA == precioB}") //false
println(s"¿precioA es mayor o igual?       ${precioA > precioB}") //false
println(f"La diferencia es:                ${precioB - precioA}%.2f €") //17.51 €
// Out:
// ¿precioA es menor que precioB?   true
// ¿Son iguales?                    false
// ¿precioA es mayor o igual?       false
// La diferencia es:                17.51 €
// precioA: Double = 49.99
// precioB: Double = 67.5

// %% [markdown]
// ### Ejercicio P4 — Etiqueta de producto
//
// Declara estas variables:
//
// - `producto = "Teclado mecánico"`
// - `precio = 89.99`
// - `unidades = 3`
// - `enStock = true`
//
// Construye e imprime la siguiente etiqueta usando **únicamente** el interpolador `f`:
//
// **Salida esperada:**
//
// ```
// Producto:  Teclado mecánico
// Precio:    89.99 €
// Unidades:  3
// Subtotal:  269.97 €
// En stock:  true
// ```

// %%
val producto    = "Teclado mecánico"
val precio      = 89.99
val unidades    = 3
val enStock     = true

println(f"Producto:     $producto")
println(f"Precio:       $precio%.2f €")
println(f"Unidades:     $unidades")
println(f"Subtotal:     ${precio * unidades}%.2f €")
println(f"En stock:     $enStock")
// Out:
// Producto:     Teclado mecánico
// Precio:       89.99 €
// Unidades:     3
// Subtotal:     269.97 €
// En stock:     true
// producto: String = "Teclado mecánico"
// precio: Double = 89.99
// unidades: Int = 3
// enStock: Boolean = true

// %% [markdown]
// ### Ejercicio P5 — Ruta de fichero
//
// Declara una variable `carpeta` con el valor `"Documentos"` y una variable `fichero` con el valor `"informe_2024.csv"`. Construye e imprime la ruta completa de dos formas:
//
// **Salida esperada:**
//
// ```
// Ruta con s:   C:\Usuarios\Alumno\Documentos\informe_2024.csv
// Ruta con raw: C:\Usuarios\Alumno\Documentos\informe_2024.csv
// ```
//
// > 💡 Con el interpolador `s` necesitarás escribir `\\` para obtener `\`. Con `raw` no.
// >

// %%
val carpeta = "Documentos"
val fichero = "informe_2024.csv"


println (s"Ruta con s: c:\\user\\alumno\\$carpeta\\$fichero")
// println (raw"Ruta con raw: c:\user\alumno\$carpeta\$fichero ") //SCALA 2 ok
// println(raw"""Ruta con raw: c:\user\alumno\$carpeta\$fichero """) //SCALA 3 ok
// Out:
// Ruta con s: c:\user\alumno\Documentos\informe_2024.csv
// carpeta: String = "Documentos"
// fichero: String = "informe_2024.csv"

// %% [markdown]
// ### Ejercicio P6 — Detector de tipo con `getClass`
//
// Scala permite consultar el tipo real de una variable en tiempo de ejecución con `.getClass.getSimpleName`. Declara seis variables sin especificar su tipo, una por cada tipo primitivo de la sesión (`Int`, `Long`, `Double`, `Float`, `Boolean`, `Char`), y muestra el nombre de tipo que infiere Scala para cada una.
//
// **Salida esperada:**
//
// ```
// 42          → Int
// 1000000000L → Long
// 3.14        → Double
// 3.14f       → Float
// true        → Boolean
// 'S'         → Char
// ```
//
// > 💡 Consulta: `val x = 42; println(x.getClass.getSimpleName)`
// >

// %%
val x = 42;
val l = 1000000000L 
val pi = 3.14
val pif = 3.14f
val b = true
val s = "S"


println (s"$x           -> ${x.getClass.getSimpleName}")
println (s"$l           -> ${l.getClass.getSimpleName}")
println (s"$pi          -> ${pi.getClass.getSimpleName}")
println (s"$pif         -> ${pif.getClass.getSimpleName}")
println (s"$b           -> ${b.getClass.getSimpleName}")
println (s"$s           -> ${s.getClass.getSimpleName}")
// Out:
// 42           -> int
// 1000000000           -> long
// 3.14          -> double
// 3.14         -> float
// true           -> boolean
// S           -> String
// x: Int = 42
// l: Long = 1000000000L
// pi: Double = 3.14
// pif: Float = 3.14F
// b: Boolean = true
// s: String = "S"

// %% [markdown]
// ### Ejercicio P7 — Ticket de compra con IVA desglosado
//
// Declara tres productos con su precio base (sin IVA). El IVA general es del 21%. Calcula e imprime el ticket con el precio base, el importe del IVA y el precio final de cada producto, más los totales. Usa el interpolador `f` para todo el formato.
//
// **Salida esperada:**
//
// ```
// ========================================
//            TICKET DE COMPRA
// ========================================
// Producto          Base     IVA    Total
// ----------------------------------------
// Monitor 4K      299.99   63.00  362.99 €
// Teclado          49.99   10.50   60.49 €
// Ratón             29.99    6.30   36.29 €
// ----------------------------------------
// TOTAL           379.97   79.79  459.76 €
// ========================================
// ```
//
// > 💡 Declara los precios base como `val`. El IVA y los totales derívales con expresiones, no con nuevas variables `var`.
// >

// %%
val monitor = 299.99
val teclado = 49.99
val raton   = 29.99

val ancho   = 40
val IVA     = 0.21

println("=" * ancho)
println("           TICKET DE COMPRA" )
println("=" * ancho)
println(s"Producto \tBase \tIVA \tTotal" )
println("-" * ancho)
println(f"Monitor 4k    \t$monitor \t${monitor * IVA}%.2f \t${monitor * (1+IVA)}%.2f €" )
println(f"Teclado       \t$teclado \t${teclado * IVA}%.2f \t${teclado * (1+IVA)}%.2f €" )
println(f"Ratón         \t$raton \t${raton * IVA}%.2f \t${raton * (1+IVA)}%.2f €" )
println("-" * ancho)
val total = monitor+teclado+raton
println(f"TOTAL         \t${total} \t${total * IVA}%.2f \t${total * (1+IVA)}%.2f €" )
println("=" * ancho)
// Out:
// ========================================
//            TICKET DE COMPRA
// ========================================
// Producto 	Base 	IVA 	Total
// ----------------------------------------
// Monitor 4k    	299.99 	63.00 	362.99 €
// Teclado       	49.99 	10.50 	60.49 €
// Ratón         	29.99 	6.30 	36.29 €
// ----------------------------------------
// TOTAL         	379.97 	79.79 	459.76 €
// ========================================
// monitor: Double = 299.99
// teclado: Double = 49.99
// raton: Double = 29.99
// ancho: Int = 40
// IVA: Double = 0.21
// total: Double = 379.97

// %% [markdown]
// ### Ejercicio P8 — Análisis de una nota
//
// Declara `val nota: Double = 6.85`. A partir de **solo esa variable**, calcula e imprime todo lo siguiente usando únicamente operadores y los tres interpoladores (`s`, `f`, `raw`):
//
// **Salida esperada:**
//
// ```
// Nota:              6.85
// Nota redondeada:   6.9
// ¿Aprobado?         true
// ¿Notable o más?    false
// Sobre 100:         68.5
// Déficit a 10:      3.15
// Informe guardado en: C:\Notas\informe_nota_6.85.txt
// ```
//
// > 💡 Para `Nota redondeada` usa `f"$nota%.1f"`. Para la ruta del fichero, construye el nombre dinámicamente incluyendo la nota con el interpolador `s` dentro de `raw`.
// >

// %%
val nota: Double = 6.85

println (s"Nota:                $nota")
println (f"Nota:                $nota%.1f")
println (f"¿Aprobado?:          ${5 < nota}")
println (f"¿Notable o más?:     ${8 < nota}")
println (f"Sobre 100:           ${nota * 100 / 10}%.1f")
println (f"Deficit a 10:        ${10 - nota}%.2f")
println (raw"Informe en:          c:\notas\informe_nota_${nota}.txt")
// Out:
// Nota:                6.85
// Nota:                6.9
// ¿Aprobado?:          true
// ¿Notable o más?:     false
// Sobre 100:           68.5
// Deficit a 10:        3.15
// Informe en:          c:\notas\informe_nota_6.85.txt
// nota: Double = 6.85

// %% [markdown]
// ### Ejercicio P9 — Validador de credenciales
//
// Declara las siguientes variables:
//
// ```scala
// val usuario       = "admin"
// val contrasena    = "Scala2024"
// val intentos: Int = 3
// val bloqueado     = intentos >= 3
// ```
//
// Usando **operadores lógicos** (`&&`, `||`, `!`), calcula e imprime:
//
// **Salida esperada:**
//
// ```scala
// ¿Usuario correcto?         true
// ¿Contraseña correcta?      true
// ¿Cuenta bloqueada?         true
// ¿Puede acceder?            false
// ¿Necesita resetear clave?  true
// ```
//
// > Donde "puede acceder" es `true` solo si el usuario es correcto, la contraseña es correcta Y la cuenta NO está bloqueada. Y "necesita resetear clave" es `true` si está bloqueado O la contraseña no es correcta.
// >

// %%
val usuario       = "admin"
val contrasena    = "Scala2024"
val intentos: Int = 3
val bloqueado     = intentos >= 3

// Usando **operadores lógicos** (`&&`, `||`, `!`), calcula e imprime:

val usuarioCorrecto     = usuario == "admin"
val contraseñaCorrecta  = contrasena == "Scala2024"
val cuentaBloqueada     = intentos  >= 3

val puedeAcceder        = usuarioCorrecto && contraseñaCorrecta && !cuentaBloqueada

val necesitaResetear    = cuentaBloqueada || !contraseñaCorrecta
// Out:
// usuario: String = "admin"
// contrasena: String = "Scala2024"
// intentos: Int = 3
// bloqueado: Boolean = true
// usuarioCorrecto: Boolean = true
// contraseñaCorrecta: Boolean = true
// cuentaBloqueada: Boolean = true
// puedeAcceder: Boolean = false
// necesitaResetear: Boolean = true

// %% [markdown]
// ### Ejercicio P10 — Conversor de unidades múltiple
//
// Declara `val distanciaKm: Double = 142.5`. A partir de **solo esa variable**, calcula la equivalencia en las cuatro unidades siguientes y muestra la tabla con el interpolador `f`:
//
// - **Metros:** 1 km = 1.000 m
// - **Millas:** 1 km = 0.621371 millas
// - **Pies:** 1 km = 3.280,84 pies
// - **Pulgadas:** 1 km = 39.370,1 pulgadas
//
// **Salida esperada:**
//
// ```scala
// === Conversor de distancia ===
// Distancia original:   142.50 km
//
// En metros:       142500.00 m
// En millas:           88.55 millas
// En pies:         467369.70 pies
// En pulgadas:    5608436.43 pulgadas
// ```
//
// > 💡 Declara los factores de conversión como `val` con nombre descriptivo antes de calcular. Usa `%12.2f` para alinear los números a la derecha.
// >

// %%
val distanciaKm: Double = 142.5

val Metros      = 1000
val Millas      = 0.621371
val Pies        = 3280.84
val Pulgadas    = 39370.1

val enMetros    = distanciaKm * Metros
val enMillas    = distanciaKm * Millas
val enPies      = distanciaKm * Pies
val enPulgadas  = distanciaKm * Pulgadas

println (f"Distancia:   $distanciaKm km")
println (f"En metros:   ${enMetros}%.2f m")
println (f"En millas:   ${enMillas}%.2f mi")
println (f"En pies:     ${enPies}%.2f ft")
println (f"En pulgadas: ${enPulgadas}%.2f in")
// Out:
// Distancia:   142.5 km
// En metros:   142500.00 m
// En millas:   88.55 mi
// En pies:     467519.70 ft
// En pulgadas: 5610239.25 in
// distanciaKm: Double = 142.5
// Metros: Int = 1000
// Millas: Double = 0.621371
// Pies: Double = 3280.84
// Pulgadas: Double = 39370.1
// enMetros: Double = 142500.0
// enMillas: Double = 88.5453675
// enPies: Double = 467519.7
// enPulgadas: Double = 5610239.25
