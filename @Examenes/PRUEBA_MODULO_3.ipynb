// %% [markdown]
// ---
// # 📄PRUEBA MODULO 3
//
// # 🏢 Caso de Estudio Propuesto — UrbanRent Analytics
//
// > **Cobertura de sesiones:**
// >
// > - Clase 15 Sesión 2 — Spark DataFrames I: Introducción (crear, cargar, explorar)
// > - Clase 16 Sesión 2 — Spark DataFrames I: Introducción (mismos contenidos, verificado)
// > - Clase 17 Sesión 1 — Operaciones básicas (select, filter, withColumn, orderBy, drop, dropDuplicates)
// > - Clase 17 Sesión 2 — Agregaciones (groupBy, agg, Window, rollup, cube, pivot)
// > - Clase 18 Sesión 1 — Joins (inner, left, right, full, semi, anti, cross, broadcast)
// > - Clase 19 Sesión 1 — Funciones integradas y UDFs (texto, fecha, arrays, UDF)
//
//
// ## 🌆 Contexto del caso
//
// **UrbanRent Analytics** es una empresa española de alquiler de apartamentos turísticos con presencia en cinco ciudades. Gestiona tres tipos de información:
//
// - Un fichero **CSV** con el registro de todas las **reservas** realizadas durante 2025.
// - Un fichero **CSV** con el catálogo de **apartamentos** disponibles y sus características.
// - Un fichero **JSON** con el perfil de los **propietarios** de cada apartamento.
//
// El equipo de datos acaba de centralizar toda la información en Apache Spark y necesita construir un pipeline de análisis completo para responder preguntas estratégicas de la dirección.
//
// > ⚠️ **Importante:** Las preguntas están agrupadas por sesión. Cada sección solo utiliza las herramientas vistas en esa sesión concreta. Trabaja en orden.
// >
//
// ---

// %% [markdown]
// ## 📦 Datos del caso
//
// Crea los siguientes ficheros antes de abrir el notebook.

// %% [markdown]
// ---
//
// ### Fichero 1 — `reservas.csv`

// %% [markdown]
// ```
// id_reserva,id_apartamento,fecha_entrada,fecha_salida,num_huespedes,precio_noche,canal,valoracion,ciudad
// R001,APT001,2025-01-10,2025-01-13,2,95.0,Airbnb,4.8,Madrid
// R002,APT002,2025-01-12,2025-01-15,4,120.0,Booking,4.5,Barcelona
// R003,APT003,2025-01-20,2025-01-22,1,75.0,Directo,5.0,Valencia
// R004,APT001,2025-02-01,2025-02-05,3,95.0,Airbnb,4.7,Madrid
// R005,APT004,2025-02-10,2025-02-12,2,110.0,Booking,4.2,Sevilla
// R006,APT002,2025-02-14,2025-02-17,5,120.0,Airbnb,4.9,Barcelona
// R007,APT005,2025-02-20,2025-02-23,2,85.0,Directo,4.6,Bilbao
// R008,APT003,2025-03-01,2025-03-04,1,75.0,Booking,4.4,Valencia
// R009,APT001,2025-03-10,2025-03-14,4,95.0,Airbnb,4.8,Madrid
// R010,APT006,2025-03-15,2025-03-17,2,130.0,Directo,5.0,Madrid
// R011,APT004,2025-03-20,2025-03-22,3,110.0,Airbnb,4.3,Sevilla
// R012,APT007,2025-04-01,2025-04-04,2,90.0,Booking,4.5,Barcelona
// R013,APT005,2025-04-08,2025-04-10,1,85.0,Directo,4.7,Bilbao
// R014,APT006,2025-04-12,2025-04-16,3,130.0,Airbnb,4.9,Madrid
// R015,APT002,2025-04-20,2025-04-23,4,120.0,Booking,4.6,Barcelona
// R016,APT008,2025-05-01,2025-05-04,2,70.0,Directo,4.1,Valencia
// R017,APT003,2025-05-10,2025-05-13,2,75.0,Airbnb,4.5,Valencia
// R018,APT007,2025-05-15,2025-05-18,3,90.0,Booking,4.8,Barcelona
// R019,APT001,2025-05-20,2025-05-24,2,95.0,Directo,5.0,Madrid
// R020,APT009,2025-05-25,2025-05-28,1,65.0,Airbnb,3.9,Bilbao
// R021,APT006,2025-06-01,2025-06-05,4,130.0,Booking,4.7,Madrid
// R022,APT010,2025-06-08,2025-06-10,2,80.0,Directo,4.3,Sevilla
// R023,APT004,2025-06-15,2025-06-18,3,110.0,Airbnb,4.6,Sevilla
// R024,APT008,2025-06-20,2025-06-22,1,70.0,Booking,4.2,Valencia
// R025,APT005,2025-06-25,2025-06-28,2,85.0,Directo,4.8,Bilbao
// ````

// %% [markdown]
// ---
//
// ### Fichero 2 — `apartamentos.csv`

// %% [markdown]
// ```
// id_apartamento,tipo,habitaciones,metros_cuadrados,tiene_parking,propietario_id,activo
// APT001,Estudio,1,35,false,P01,true
// APT002,Piso,3,85,true,P02,true
// APT003,Estudio,1,30,false,P01,true
// APT004,Piso,2,65,true,P03,true
// APT005,Ático,2,70,true,P04,true
// APT006,Piso,3,90,true,P02,true
// APT007,Estudio,1,28,false,P05,true
// APT008,Estudio,1,32,false,P03,false
// APT009,Piso,2,55,false,P04,true
// APT010,Ático,3,100,true,P05,true
// ```

// %% [markdown]
// ---
//
// ### Fichero 3 — `propietarios.json`

// %% [markdown]
// ```json
// [
//   {"propietario_id": "P01", "nombre": "Laura Sánchez", "ciudad": "Madrid", "antiguedad_anios": 5, "tipo_contrato": "Premium", "especialidades": ["Estudio","Piso"]},
//   {"propietario_id": "P02", "nombre": "Carlos Méndez", "ciudad": "Barcelona", "antiguedad_anios": 3, "tipo_contrato": "Estándar", "especialidades": ["Piso"]},
//   {"propietario_id": "P03", "nombre": "Ana Ferrero", "ciudad": "Sevilla", "antiguedad_anios": 7, "tipo_contrato": "Premium", "especialidades": ["Piso","Ático"]},
//   {"propietario_id": "P04", "nombre": "Javier Ruiz", "ciudad": "Bilbao", "antiguedad_anios": 2, "tipo_contrato": "Estándar", "especialidades": ["Ático","Piso"]},
//   {"propietario_id": "P05", "nombre": "Marta Gil", "ciudad": "Valencia", "antiguedad_anios": 6, "tipo_contrato": "Premium", "especialidades": ["Estudio","Ático"]}
// ]
// ```

// %% [markdown]
// ---
//
// ## ⚙️ Celda 0 — Inicialización del entorno (obligatoria)
//
// Ejecuta esta celda antes de cualquier otra.

// %%
// Celda 0 — Inicialización
import $ivy.`org.apache.spark::spark-core:4.1.1`
import $ivy.`org.apache.spark::spark-sql:4.1.1`

import org.apache.spark.sql.SparkSession
import org.apache.spark.sql.functions._
import org.apache.spark.sql.expressions.Window
import org.apache.spark.sql.types._

val spark = SparkSession.builder()
  .appName("UrbanRent_Analytics")
  .master("local[*]")
  .config("spark.sql.shuffle.partitions", "4")
  .config("spark.sql.crossJoin.enabled", "true")
  .getOrCreate()

import spark.implicits._
spark.sparkContext.setLogLevel("ERROR")

println(s"✅ UrbanRent Analytics iniciado — Spark ${spark.version} · Scala ${scala.util.Properties.versionString}")
// Out:
// Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
// 26/05/02 08:10:01 INFO SparkContext: Running Spark version 4.1.1
// 26/05/02 08:10:01 INFO SparkContext: OS info Linux, 6.6.87.2-microsoft-standard-WSL2, amd64
// 26/05/02 08:10:01 INFO SparkContext: Java version 17.0.18+8-Ubuntu-122.04.1
// 26/05/02 08:10:01 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
// 26/05/02 08:10:01 INFO ResourceUtils: ==============================================================
// 26/05/02 08:10:01 INFO ResourceUtils: No custom resources configured for spark.driver.
// 26/05/02 08:10:01 INFO ResourceUtils: ==============================================================
// 26/05/02 08:10:01 INFO SparkContext: Submitted application: UrbanRent_Analytics
// 26/05/02 08:10:02 INFO SecurityManager: Changing view acls to: root
// 26/05/02 08:10:02 INFO SecurityManager: Changing modify acls to: root
// 26/05/02 08:10:02 INFO SecurityManager: Changing view acls groups to: root
// 26/05/02 08:10:02 INFO SecurityManager: Changing modify acls groups to: root
// 26/05/02 08:10:02 INFO SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users with view permissions: root groups with view permissions: EMPTY; users with modify permissions: root; groups with modify permissions: EMPTY; RPC SSL disabled
// 26/05/02 08:10:02 INFO Utils: Successfully started service 'sparkDriver' on port 46121.
// 26/05/02 08:10:02 INFO SparkEnv: Registering MapOutputTracker
// 26/05/02 08:10:02 INFO SparkEnv: Registering BlockManagerMaster
// 26/05/02 08:10:02 INFO BlockManagerMasterEndpoint: Using org.apache.spark.storage.DefaultTopologyMapper for getting topology information
// 26/05/02 08:10:02 INFO BlockManagerMasterEndpoint: BlockManagerMasterEndpoint up
// 26/05/02 08:10:02 INFO SparkEnv: Registering BlockManagerMasterHeartbeat
// 26/05/02 08:10:02 INFO DiskBlockManager: Created local directory at /tmp/blockmgr-f48951fc-747c-4e10-8bf2-c1e61eb1ea6f
// 26/05/02 08:10:02 INFO SparkEnv: Registering OutputCommitCoordinator
// 26/05/02 08:10:03 INFO JettyUtils: Start Jetty 0.0.0.0:4040 for SparkUI
// 26/05/02 08:10:03 INFO Utils: Successfully started service 'SparkUI' on port 4040.
// 26/05/02 08:10:03 INFO ResourceProfile: Default ResourceProfile created, executor resources: Map(cores -> name: cores, amount: 1, script: , vendor: , memory -> name: memory, amount: 1024, script: , vendor: , offHeap -> name: offHeap, amount: 0, script: , vendor: ), task resources: Map(cpus -> name: cpus, amount: 1.0)
// 26/05/02 08:10:03 INFO ResourceProfile: Limiting resource is cpu
// 26/05/02 08:10:03 INFO ResourceProfileManager: Added ResourceProfile id: 0
// 26/05/02 08:10:03 INFO SecurityManager: Changing view acls to: root
// 26/05/02 08:10:03 INFO SecurityManager: Changing modify acls to: root
// 26/05/02 08:10:03 INFO SecurityManager: Changing view acls groups to: root
// 26/05/02 08:10:03 INFO SecurityManager: Changing modify acls groups to: root
// 26/05/02 08:10:03 INFO SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users with view permissions: root groups with view permissions: EMPTY; users with modify permissions: root; groups with modify permissions: EMPTY; RPC SSL disabled
// 26/05/02 08:10:03 INFO Executor: Starting executor ID driver on host c3fd9529283d
// 26/05/02 08:10:03 INFO Executor: OS info Linux, 6.6.87.2-microsoft-standard-WSL2, amd64
// 26/05/02 08:10:03 INFO Executor: Java version 17.0.18+8-Ubuntu-122.04.1
// 26/05/02 08:10:03 INFO Executor: Starting executor with user classpath (userClassPathFirst = false): ''
// 26/05/02 08:10:03 INFO Executor: Created or updated repl class loader org.apache.spark.util.MutableURLClassLoader@8392f3e for default.
// 26/05/02 08:10:03 INFO Utils: Successfully started service 'org.apache.spark.network.netty.NettyBlockTransferService' on port 41053.
// 26/05/02 08:10:03 INFO NettyBlockTransferService: Server created on c3fd9529283d:41053
// 26/05/02 08:10:03 INFO BlockManager: Using org.apache.spark.storage.RandomBlockReplicationPolicy for block replication policy
// 26/05/02 08:10:03 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, c3fd9529283d, 41053, None)
// 26/05/02 08:10:03 INFO BlockManagerMasterEndpoint: Registering block manager c3fd9529283d:41053 with 952.8 MiB RAM, BlockManagerId(driver, c3fd9529283d, 41053, None)
// 26/05/02 08:10:03 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, c3fd9529283d, 41053, None)
// 26/05/02 08:10:03 INFO BlockManager: Initialized BlockManager: BlockManagerId(driver, c3fd9529283d, 41053, None)
// ✅ UrbanRent Analytics iniciado — Spark 4.1.1 · Scala version 2.13.18
// import $ivy.$
// import $ivy.$
// import org.apache.spark.sql.SparkSession
// import org.apache.spark.sql.functions._
// import org.apache.spark.sql.expressions.Window
// import org.apache.spark.sql.types._
// spark: SparkSession = org.apache.spark.sql.classic.SparkSession@1a773689
// import spark.implicits._

// %% [markdown]
// **Salida esperada:**
//
// ```
// ✅ UrbanRent Analytics iniciado — Spark 4.1.1 · Scala version 2.13.18
// ```

// %% [markdown]
// ---
//
// ## 🗂️ PARTE 1 — Carga y exploración inicial

// %% [markdown]
// ---
//
// ### Pregunta 1 — ¿Están bien formateados nuestros datos de reservas?
//
// El responsable de datos quiere verificar que Spark ha inferido correctamente los tipos antes de avanzar con cualquier análisis.
//
// **Lo que debes hacer:**
//
// 1. Carga `reservas.csv` con `header = true` e `inferSchema = true`. Llama al DataFrame `reservas`.
// 2. Muestra las primeras 8 filas con `show(8)`.
// 3. Imprime el schema completo con `printSchema()`.
// 4. Muestra estadísticas descriptivas de `precio_noche`, `num_huespedes` y `valoracion` con `describe()`.
// 5. Imprime el número total de reservas con `count()` y lista todas las columnas con `columns`.
//
// **Salida esperada (parcial):**
//
// ```
// === Primeras 8 reservas ===
// +-----------+---------------+-------------+------------+--------------+------------+-------+----------+--------+
// |id_reserva |id_apartamento |fecha_entrada |fecha_salida|num_huespedes |precio_noche|canal  |valoracion|ciudad  |
// +-----------+---------------+-------------+------------+--------------+------------+-------+----------+--------+
// |R001       |APT001         |2025-01-10   |2025-01-13  |2             |95.0        |Airbnb |4.8       |Madrid  |
// ...
//
// Total de reservas: 25
// Columnas: id_reserva | id_apartamento | fecha_entrada | fecha_salida | num_huespedes | precio_noche | canal | valoracion | ciudad
// ```

// %%
val reservas = spark.read
    .option("header", "true")
    .option("inferSchema", "true")  // detectar tipos automáticamente
    .csv("./datos/UrbanRent/reservas.csv")

reservas.show(8)
reservas.printSchema()
reservas.describe("precio_noche", "num_huespedes", "valoracion").show()
println(s"# Reservas: ${reservas.count()}")
println(s"  Columnas: ${reservas.columns.mkString("|")}")
// Out:
// +----------+--------------+-------------+------------+-------------+------------+-------+----------+---------+
// |id_reserva|id_apartamento|fecha_entrada|fecha_salida|num_huespedes|precio_noche|  canal|valoracion|   ciudad|
// +----------+--------------+-------------+------------+-------------+------------+-------+----------+---------+
// |      R001|        APT001|   2025-01-10|  2025-01-13|            2|        95.0| Airbnb|       4.8|   Madrid|
// |      R002|        APT002|   2025-01-12|  2025-01-15|            4|       120.0|Booking|       4.5|Barcelona|
// |      R003|        APT003|   2025-01-20|  2025-01-22|            1|        75.0|Directo|       5.0| Valencia|
// |      R004|        APT001|   2025-02-01|  2025-02-05|            3|        95.0| Airbnb|       4.7|   Madrid|
// |      R005|        APT004|   2025-02-10|  2025-02-12|            2|       110.0|Booking|       4.2|  Sevilla|
// |      R006|        APT002|   2025-02-14|  2025-02-17|            5|       120.0| Airbnb|       4.9|Barcelona|
// |      R007|        APT005|   2025-02-20|  2025-02-23|            2|        85.0|Directo|       4.6|   Bilbao|
// |      R008|        APT003|   2025-03-01|  2025-03-04|            1|        75.0|Booking|       4.4| Valencia|
// +----------+--------------+-------------+------------+-------------+------------+-------+----------+---------+
// only showing top 8 rows
// root
//  |-- id_reserva: string (nullable = true)
//  |-- id_apartamento: string (nullable = true)
//  |-- fecha_entrada: date (nullable = true)
//  |-- fecha_salida: date (nullable = true)
//  |-- num_huespedes: integer (nullable = true)
//  |-- precio_noche: double (nullable = true)
//  |-- canal: string (nullable = true)
//  |-- valoracion: double (nullable = true)
//  |-- ciudad: string (nullable = true)
//
// +-------+------------------+-----------------+-------------------+
// |summary|      precio_noche|    num_huespedes|         valoracion|
// +-------+------------------+-----------------+-------------------+
// |  count|                25|               25|                 25|
// |   mean|              96.2|             2.44|              4.592|
// | stddev|20.528435563059027|1.121011448053349|0.29988886830513284|
// |    min|              65.0|                1|                3.9|
// |    max|             130.0|                5|                5.0|
// +-------+------------------+-----------------+-------------------+
//
// # Reservas: 25
//   Columnas: id_reserva|id_apartamento|fecha_entrada|fecha_salida|num_huespedes|precio_noche|canal|valoracion|ciudad
// reservas: org.apache.spark.sql.package.DataFrame = [id_reserva: string, id_apartamento: string ... 7 more fields]

// %% [markdown]
// ---
//
// ### Pregunta 2 — ¿Es correcto el schema inferido o necesitamos ajustarlo?
//
// El equipo técnico señala que `fecha_entrada` y `fecha_salida` llegan como `StringType`. Para los cálculos de duración de estancias necesitarán ser `DateType`.
//
// **Lo que debes hacer:**
//
// 1. Define un `StructType` manual para `reservas` con al menos estos ajustes:
//     - `fecha_entrada` y `fecha_salida` como `DateType` (usa `to_date` o define el tipo en el schema).
//     - `precio_noche` como `DoubleType`.
//     - `valoracion` como `DoubleType`.
//     - `num_huespedes` como `IntegerType`.
// 2. Recarga `reservas.csv` usando `.schema(...)` en lugar de `inferSchema`.
// 3. Verifica con `printSchema()` que los tipos son ahora los correctos.
//
// **Pista:** Para leer fechas con schema manual en CSV usa `.option("dateFormat", "yyyy-MM-dd")`.

// %%
val schemaReservas = StructType(List(
  StructField("id_reserva",       StringType, nullable = false),
  StructField("id_apartamento",   StringType, nullable = false),
  StructField("fecha_entrada",    DateType, nullable = true),
  StructField("fecha_salida",     DateType, nullable = true),
  StructField("num_huespedes",    IntegerType, nullable = true),
  StructField("precio_noche",     DoubleType, nullable = true),
  StructField("canal",            StringType, nullable = true),
  StructField("valoracion",       DoubleType, nullable = true),
  StructField("ciudad",           StringType, nullable = true),
))

val reservas = spark.read
    .option("header", "true")
    .option("dateFormat", "yyyy-MM-dd")
    .schema(schemaReservas)
    .csv("./datos/UrbanRent/reservas.csv")

reservas.show(8)
reservas.printSchema()
// reservas.describe("precio_noche", "num_huespedes", "valoracion").show()
// println(s"# Reservas: ${reservas.count()}")
// println(s"  Columnas: ${reservas.columns.mkString("|")}")
// Out:
// +----------+--------------+-------------+------------+-------------+------------+-------+----------+---------+
// |id_reserva|id_apartamento|fecha_entrada|fecha_salida|num_huespedes|precio_noche|  canal|valoracion|   ciudad|
// +----------+--------------+-------------+------------+-------------+------------+-------+----------+---------+
// |      R001|        APT001|   2025-01-10|  2025-01-13|            2|        95.0| Airbnb|       4.8|   Madrid|
// |      R002|        APT002|   2025-01-12|  2025-01-15|            4|       120.0|Booking|       4.5|Barcelona|
// |      R003|        APT003|   2025-01-20|  2025-01-22|            1|        75.0|Directo|       5.0| Valencia|
// |      R004|        APT001|   2025-02-01|  2025-02-05|            3|        95.0| Airbnb|       4.7|   Madrid|
// |      R005|        APT004|   2025-02-10|  2025-02-12|            2|       110.0|Booking|       4.2|  Sevilla|
// |      R006|        APT002|   2025-02-14|  2025-02-17|            5|       120.0| Airbnb|       4.9|Barcelona|
// |      R007|        APT005|   2025-02-20|  2025-02-23|            2|        85.0|Directo|       4.6|   Bilbao|
// |      R008|        APT003|   2025-03-01|  2025-03-04|            1|        75.0|Booking|       4.4| Valencia|
// +----------+--------------+-------------+------------+-------------+------------+-------+----------+---------+
// only showing top 8 rows
// root
//  |-- id_reserva: string (nullable = true)
//  |-- id_apartamento: string (nullable = true)
//  |-- fecha_entrada: date (nullable = true)
//  |-- fecha_salida: date (nullable = true)
//  |-- num_huespedes: integer (nullable = true)
//  |-- precio_noche: double (nullable = true)
//  |-- canal: string (nullable = true)
//  |-- valoracion: double (nullable = true)
//  |-- ciudad: string (nullable = true)
// schemaReservas: StructType = Seq(
//   StructField(
//     name = "id_reserva",
//     dataType = StringType,
//     nullable = false,
//     metadata = {}
//   ),
//   StructField(
//     name = "id_apartamento",
//     dataType = StringType,
//     nullable = false,
//     metadata = {}
//   ),
//   StructField(
//     name = "fecha_entrada",
//     dataType = DateType,
//     nullable = true,
//     metadata = {}
//   ),
//   StructField(
//     name = "fecha_salida",
//     dataType = DateType,
//     nullable = true,
//     metadata = {}
//   ),
//   StructField(
//     name = "num_huespedes",
//     dataType = IntegerType,
//     nullable = true,
//     metadata = {}
//   ),
//   StructField(
//     name = "precio_noche",
//     dataType = DoubleType,
//     nullable = true,
//     metadata = {}
//   ),
//   StructField(
//     name = "canal",
// ...
// reservas: org.apache.spark.sql.package.DataFrame = [id_reserva: string, id_apartamento: string ... 7 more fields]

// %% [markdown]
// ---
//
// ### Pregunta 3 — ¿Cuántos apartamentos tenemos y cuáles son sus características?
//
// **Lo que debes hacer:**
//
// 1. Carga `apartamentos.csv` con `inferSchema = true`. Llama al DataFrame `apartamentos`.
// 2. Carga `propietarios.json` con `multiline = true`. Llama al DataFrame `propietarios`.
// 3. Para cada uno: muestra el schema, las primeras filas y el `count()`.
// 4. ¿Cuántos apartamentos están marcados como `activo = true`?

// %%
val apartamentos = spark.read
    .option("header", "true")
    .option("inferSchema", "true")  // detectar tipos automáticamente
    .csv("./datos/UrbanRent/apartamentos.csv")

val propietarios = spark.read
    .option("multiline", "true")    // para JSON con objetos multilínea
    .json("./datos/UrbanRent/propietarios.json")

apartamentos.show(8)
apartamentos.printSchema()
// apartamentos.describe("precio_noche", "num_huespedes", "valoracion").show()
println(s"# Apartamentos: ${apartamentos.count()}")
println(s"  Columnas: ${apartamentos.columns.mkString("|")}")

propietarios.show(8)
propietarios.printSchema()
// apartamentos.describe("precio_noche", "num_huespedes", "valoracion").show()
println(s"# propietarios: ${propietarios.count()}")
println(s"  Columnas: ${propietarios.columns.mkString("|")}")
// Out:
// +--------------+-------+------------+----------------+-------------+--------------+------+
// |id_apartamento|   tipo|habitaciones|metros_cuadrados|tiene_parking|propietario_id|activo|
// +--------------+-------+------------+----------------+-------------+--------------+------+
// |        APT001|Estudio|           1|              35|        false|           P01|  true|
// |        APT002|   Piso|           3|              85|         true|           P02|  true|
// |        APT003|Estudio|           1|              30|        false|           P01|  true|
// |        APT004|   Piso|           2|              65|         true|           P03|  true|
// |        APT005|  Ático|           2|              70|         true|           P04|  true|
// |        APT006|   Piso|           3|              90|         true|           P02|  true|
// |        APT007|Estudio|           1|              28|        false|           P05|  true|
// |        APT008|Estudio|           1|              32|        false|           P03| false|
// +--------------+-------+------------+----------------+-------------+--------------+------+
// only showing top 8 rows
// root
//  |-- id_apartamento: string (nullable = true)
//  |-- tipo: string (nullable = true)
//  |-- habitaciones: integer (nullable = true)
//  |-- metros_cuadrados: integer (nullable = true)
//  |-- tiene_parking: boolean (nullable = true)
//  |-- propietario_id: string (nullable = true)
//  |-- activo: boolean (nullable = true)
//
// # Apartamentos: 10
//   Columnas: id_apartamento|tipo|habitaciones|metros_cuadrados|tiene_parking|propietario_id|activo
// +----------------+---------+----------------+-------------+--------------+-------------+
// |antiguedad_anios|   ciudad|  especialidades|       nombre|propietario_id|tipo_contrato|
// +----------------+---------+----------------+-------------+--------------+-------------+
// |               5|   Madrid| [Estudio, Piso]|Laura Sánchez|           P01|      Premium|
// |               3|Barcelona|          [Piso]|Carlos Méndez|           P02|     Estándar|
// |               7|  Sevilla|   [Piso, Ático]|  Ana Ferrero|           P03|      Premium|
// |               2|   Bilbao|   [Ático, Piso]|  Javier Ruiz|           P04|     Estándar|
// |               6| Valencia|[Estudio, Ático]|    Marta Gil|           P05|      Premium|
// +----------------+---------+----------------+-------------+--------------+-------------+
//
// root
//  |-- antiguedad_anios: long (nullable = true)
//  |-- ciudad: string (nullable = true)
//  |-- especialidades: array (nullable = true)
//  |    |-- element: string (containsNull = true)
//  |-- nombre: string (nullable = true)
//  |-- propietario_id: string (nullable = true)
//  |-- tipo_contrato: string (nullable = true)
//
// # propietarios: 5
//   Columnas: antiguedad_anios|ciudad|especialidades|nombre|propietario_id|tipo_contrato
// apartamentos: org.apache.spark.sql.package.DataFrame = [id_apartamento: string, tipo: string ... 5 more fields]
// propietarios: org.apache.spark.sql.package.DataFrame = [antiguedad_anios: bigint, ciudad: string ... 4 more fields]

// %% [markdown]
// ---
//
// ## 🔧 PARTE 2 — Operaciones básicas sobre DataFrames
//
// ### 📌 Sesión cubierta: Clase 17 Sesión 1

// %% [markdown]
// ---
//
// ### Pregunta 4 — ¿Qué reservas corresponden a estancias de más de 3 noches?
//
// La dirección quiere un informe de reservas largas para identificar clientes de alto valor.
//
// **Lo que debes hacer:**
//
// 1. Sobre el DataFrame `reservas`, añade una columna `num_noches` calculada como `datediff($"fecha_salida", $"fecha_entrada")`.
// 2. Añade también una columna `ingreso_reserva` = `num_noches * precio_noche`.
// 3. Filtra para quedarte solo con reservas donde `num_noches > 3`.
// 4. Selecciona únicamente: `id_reserva`, `ciudad`, `canal`, `num_noches`, `ingreso_reserva`.
// 5. Ordena de mayor a menor `ingreso_reserva`.
//
// **Llama al resultado `reservasLargas` y muéstralo.**

// %%
val reservasAmpliado = reservas
    .withColumn("num_noches",       datediff($"fecha_salida", $"fecha_entrada"))
    .withColumn("ingreso_reserva",  $"num_noches" * $"precio_noche")

val reservasLargas = reservasAmpliado
    .filter($"num_noches" > 3)
    .select("id_reserva", "ciudad", "canal", "num_noches", "ingreso_reserva")
    .orderBy($"ingreso_reserva".desc)

reservasLargas.show(truncate=false)
// Out:
// +----------+------+-------+----------+---------------+
// |id_reserva|ciudad|canal  |num_noches|ingreso_reserva|
// +----------+------+-------+----------+---------------+
// |R014      |Madrid|Airbnb |4         |520.0          |
// |R021      |Madrid|Booking|4         |520.0          |
// |R004      |Madrid|Airbnb |4         |380.0          |
// |R009      |Madrid|Airbnb |4         |380.0          |
// |R019      |Madrid|Directo|4         |380.0          |
// +----------+------+-------+----------+---------------+
// reservasAmpliado: org.apache.spark.sql.package.DataFrame = [id_reserva: string, id_apartamento: string ... 9 more fields]
// reservasLargas: org.apache.spark.sql.Dataset[org.apache.spark.sql.Row] = [id_reserva: string, ciudad: string ... 3 more fields]

// %% [markdown]
// ---
//
// ### Pregunta 5 — ¿Qué canales de venta tenemos activos y cuál es el precio medio por canal?
//
// El equipo de marketing quiere un catálogo limpio de canales sin repetidos.
//
// **Lo que debes hacer:**
//
// 1. Sobre `reservas`, elimina duplicados por la columna `canal`.
// 2. Selecciona únicamente las columnas `canal` y `precio_noche`.
// 3. Ordena de mayor a menor `precio_noche`.
//
// **Pista:** Usa `dropDuplicates("canal")`.

// %%
val canalesPrecioMedio = reservas
    // .dropDuplicates("canal")
    .groupBy("canal")
    .agg(
        avg("precio_noche").as("precio_medio")
    )
    // .select("canal", "precio_noche")
    .orderBy($"precio_medio".desc)
    

reservas.select("canal").distinct().show(truncate=false)
canalesPrecioMedio.show(truncate=false)
// Out:
// +-------+
// |canal  |
// +-------+
// |Airbnb |
// |Directo|
// |Booking|
// +-------+
//
// +-------+-----------------+
// |canal  |precio_medio     |
// +-------+-----------------+
// |Booking|100.625          |
// |Airbnb |99.44444444444444|
// |Directo|88.125           |
// +-------+-----------------+
// canalesPrecioMedio: org.apache.spark.sql.Dataset[org.apache.spark.sql.Row] = [canal: string, precio_medio: double]

// %% [markdown]
// ---
//
// ### Pregunta 6 — ¿Cuánto ingresaría cada reserva si aplicáramos un suplemento del 10% para reservas con más de 2 huéspedes?
//
// **Lo que debes hacer:**
//
// 1. Añade una columna `precio_con_suplemento` usando `when`/`otherwise`:
//     - Si `num_huespedes > 2`: `precio_noche * 1.10`
//     - En otro caso: `precio_noche`
// 2. Añade `ingreso_estimado` = `num_noches * precio_con_suplemento` (asegúrate de que `num_noches` existe en el DataFrame).
// 3. Selecciona `id_reserva`, `ciudad`, `num_huespedes`, `precio_noche`, `precio_con_suplemento`, `ingreso_estimado`.
// 4. Ordena por `ingreso_estimado` descendente.

// %%
val reservasSuplemento = reservasAmpliado
    .withColumn("precio_con_suplemento",    
        when (col("num_huespedes") > 2, col("precio_noche") * 1.10)
        .otherwise (col("precio_noche"))
    )
    .withColumn("ingreso_estimado", col("num_noches") * col("precio_con_suplemento"))
    .select("id_reserva", "ciudad", "num_huespedes", "precio_noche", "precio_con_suplemento", "ingreso_estimado")
    .orderBy($"ingreso_estimado".desc)


reservasSuplemento.show(truncate=false)
// Out:
// +----------+---------+-------------+------------+---------------------+------------------+
// |id_reserva|ciudad   |num_huespedes|precio_noche|precio_con_suplemento|ingreso_estimado  |
// +----------+---------+-------------+------------+---------------------+------------------+
// |R014      |Madrid   |3            |130.0       |143.0                |572.0             |
// |R021      |Madrid   |4            |130.0       |143.0                |572.0             |
// |R004      |Madrid   |3            |95.0        |104.50000000000001   |418.00000000000006|
// |R009      |Madrid   |4            |95.0        |104.50000000000001   |418.00000000000006|
// |R002      |Barcelona|4            |120.0       |132.0                |396.0             |
// |R006      |Barcelona|5            |120.0       |132.0                |396.0             |
// |R015      |Barcelona|4            |120.0       |132.0                |396.0             |
// |R019      |Madrid   |2            |95.0        |95.0                 |380.0             |
// |R023      |Sevilla  |3            |110.0       |121.00000000000001   |363.00000000000006|
// |R018      |Barcelona|3            |90.0        |99.00000000000001    |297.00000000000006|
// |R001      |Madrid   |2            |95.0        |95.0                 |285.0             |
// |R012      |Barcelona|2            |90.0        |90.0                 |270.0             |
// |R010      |Madrid   |2            |130.0       |130.0                |260.0             |
// |R007      |Bilbao   |2            |85.0        |85.0                 |255.0             |
// |R025      |Bilbao   |2            |85.0        |85.0                 |255.0             |
// |R011      |Sevilla  |3            |110.0       |121.00000000000001   |242.00000000000003|
// |R008      |Valencia |1            |75.0        |75.0                 |225.0             |
// |R017      |Valencia |2            |75.0        |75.0                 |225.0             |
// |R005      |Sevilla  |2            |110.0       |110.0                |220.0             |
// |R016      |Valencia |2            |70.0        |70.0                 |210.0             |
// +----------+---------+-------------+------------+---------------------+------------------+
// only showing top 20 rows
// reservasSuplemento: org.apache.spark.sql.Dataset[org.apache.spark.sql.Row] = [id_reserva: string, ciudad: string ... 4 more fields]

// %% [markdown]
// ---
//
// ### Pregunta 7 — ¿Existen ciudades con reservas en el dataset de apartamentos que no aparecen en el de reservas?
//
// **Lo que debes hacer:**
//
// 1. Renombra la columna `ciudad` del DataFrame de propietarios a `ciudad_propietario` para evitar ambigüedades.
// 2. Muestra las ciudades únicas en `reservas` con `select("ciudad").distinct()`.
// 3. Muestra las ciudades únicas en `propietarios` (columna `ciudad`) con `select("ciudad").distinct()`.

// %%
val ciudadesPropietario = propietarios
    .withColumnRenamed("ciudad", "ciudad_propietario")
    .select("ciudad_propietario").distinct()
    // .show()

val ciudadesReservas = reservas
    .select("ciudad").distinct()
    // .show()

val apartamentosSinReservas = ciudadesPropietario
    .join(ciudadesReservas, col("ciudad_propietario") === col("ciudad"), "anti")


apartamentosSinReservas.show()
// Out:
// +------------------+
// |ciudad_propietario|
// +------------------+
// +------------------+
// ciudadesPropietario: org.apache.spark.sql.Dataset[org.apache.spark.sql.Row] = [ciudad_propietario: string]
// ciudadesReservas: org.apache.spark.sql.Dataset[org.apache.spark.sql.Row] = [ciudad: string]
// apartamentosSinReservas: org.apache.spark.sql.package.DataFrame = [ciudad_propietario: string]

// %% [markdown]
// ---
//
// ## 📊 PARTE 3 — Agregaciones y métricas de negocio
//
// ### 📌 Sesión cubierta: Clase 17 Sesión 2

// %% [markdown]
// ---
//
// ### Pregunta 8 — ¿Qué ciudad genera más ingresos para la empresa?
//
// **Lo que debes hacer:**
//
// 1. Parte del DataFrame que ya tiene la columna `ingreso_reserva` (Pregunta 4, o recalcúlala si es necesario).
// 2. Agrupa por `ciudad` y calcula:
//     - `num_reservas` = número de reservas
//     - `ingreso_total` = suma de `ingreso_reserva`
//     - `ticket_medio` = promedio de `ingreso_reserva`
//     - `valoracion_media` = promedio de `valoracion`
// 3. Ordena por `ingreso_total` descendente.

// %%
val topIngresos = reservasAmpliado
    .groupBy("ciudad")
    .agg(
        count("id_reserva").as("num_reservas"),
        sum("ingreso_reserva").as("ingreso_total"),
        avg("ingreso_reserva").as("ticket_medio"),
        avg("valoracion").as("valoracion_media")
    )
    .orderBy($"ingreso_total".desc)

topIngresos.show()
// Out:
// +---------+------------+-------------+-----------------+------------------+
// |   ciudad|num_reservas|ingreso_total|     ticket_medio|  valoracion_media|
// +---------+------------+-------------+-----------------+------------------+
// |   Madrid|           7|       2725.0|389.2857142857143| 4.842857142857143|
// |Barcelona|           5|       1620.0|            324.0|              4.66|
// | Valencia|           5|        950.0|            190.0|4.4399999999999995|
// |  Sevilla|           4|        930.0|            232.5|              4.35|
// |   Bilbao|           4|        875.0|           218.75|               4.5|
// +---------+------------+-------------+-----------------+------------------+
// topIngresos: org.apache.spark.sql.Dataset[org.apache.spark.sql.Row] = [ciudad: string, num_reservas: bigint ... 3 more fields]

// %% [markdown]
// ---
//
// ### Pregunta 9 — ¿Cuál es el canal de venta más rentable por ciudad?
//
// La dirección quiere saber si Airbnb, Booking o el canal Directo domina en cada ciudad.
//
// **Lo que debes hacer:**
//
// 1. Agrupa por `ciudad` y `canal`.
// 2. Calcula `ingreso_total` = suma de `ingreso_reserva` y `num_reservas` = count.
// 3. Ordena por `ciudad` y `ingreso_total` descendente.

// %%
val canalRentable = reservasAmpliado
    .groupBy("ciudad", "canal")
    .agg(
        count("id_reserva").as("num_reservas"),
        sum("ingreso_reserva").as("ingreso_total")
    )
    .orderBy($"ciudad", $"ingreso_total".desc)

canalRentable.show(truncate=false)
// Out:
// +---------+-------+------------+-------------+
// |ciudad   |canal  |num_reservas|ingreso_total|
// +---------+-------+------------+-------------+
// |Barcelona|Booking|4           |1260.0       |
// |Barcelona|Airbnb |1           |360.0        |
// |Bilbao   |Directo|3           |680.0        |
// |Bilbao   |Airbnb |1           |195.0        |
// |Madrid   |Airbnb |4           |1565.0       |
// |Madrid   |Directo|2           |640.0        |
// |Madrid   |Booking|1           |520.0        |
// |Sevilla  |Airbnb |2           |550.0        |
// |Sevilla  |Booking|1           |220.0        |
// |Sevilla  |Directo|1           |160.0        |
// |Valencia |Booking|2           |365.0        |
// |Valencia |Directo|2           |360.0        |
// |Valencia |Airbnb |1           |225.0        |
// +---------+-------+------------+-------------+
// canalRentable: org.apache.spark.sql.Dataset[org.apache.spark.sql.Row] = [ciudad: string, canal: string ... 2 more fields]

// %% [markdown]
// ---
//
// ### Pregunta 10 — ¿Qué apartamento tiene la mejor posición de ingreso dentro de su ciudad?
//
// **Lo que debes hacer:**
//
// 1. Calcula primero `ingreso_reserva` si no existe todavía.
// 2. Agrupa por `id_apartamento` y `ciudad`, calcula `ingreso_total` = suma de `ingreso_reserva`.
// 3. Define una ventana `ventanaCiudad` con `partitionBy("ciudad")` y `orderBy($"ingreso_total".desc)`.
// 4. Añade la columna `ranking_ciudad` usando `rank()` sobre esa ventana.
// 5. Filtra para ver solo el apartamento en posición 1 de cada ciudad.
// 6. Ordena por `ingreso_total` descendente.

// %%
val ingresosPorApartamento = reservasAmpliado
	.groupBy("id_apartamento", "ciudad")
	.agg(sum("ingreso_reserva").as("ingreso_total"))

val ventanaCiudad = Window.partitionBy("ciudad").orderBy($"ingreso_total".desc)

val topAptPorCiudad = ingresosPorApartamento
	.withColumn("ranking_ciudad", rank().over(ventanaCiudad))
	.filter($"ranking_ciudad" === 1)
	.orderBy($"ingreso_total".desc)

topAptPorCiudad.show(truncate = false)
// Out:
// +--------------+---------+-------------+--------------+
// |id_apartamento|ciudad   |ingreso_total|ranking_ciudad|
// +--------------+---------+-------------+--------------+
// |APT001        |Madrid   |1425.0       |1             |
// |APT002        |Barcelona|1080.0       |1             |
// |APT004        |Sevilla  |770.0        |1             |
// |APT005        |Bilbao   |680.0        |1             |
// |APT003        |Valencia |600.0        |1             |
// +--------------+---------+-------------+--------------+
// ingresosPorApartamento: org.apache.spark.sql.package.DataFrame = [id_apartamento: string, ciudad: string ... 1 more field]
// ventanaCiudad: org.apache.spark.sql.expressions.WindowSpec = org.apache.spark.sql.expressions.WindowSpec@2f633905
// topAptPorCiudad: org.apache.spark.sql.Dataset[org.apache.spark.sql.Row] = [id_apartamento: string, ciudad: string ... 2 more fields]

// %% [markdown]
// ---
//
// ### Pregunta 11 — ¿Cuánto se ha facturado en total por ciudad y canal, con subtotales?
//
// El CFO necesita un informe con subtotales por ciudad y también el gran total global para cuadrar con contabilidad.
//
// **Lo que debes hacer:**
//
// 1. Usa `rollup("ciudad", "canal")` sobre el DataFrame con `ingreso_reserva`.
// 2. Agrega `sum("ingreso_reserva").as("total_facturado")`.
// 3. Ordena por `ciudad`, `canal`.
// 4. Muestra el resultado completo.
//
// **Reflexión:** ¿Qué representan las filas donde `canal` es `null`? ¿Y la fila donde ambas columnas son `null`?

// %%
val facturacionPorCiudadCanal = reservasAmpliado
    .rollup("ciudad", "canal")
    .agg(sum("ingreso_reserva").as("total_facturado"))
    .orderBy("ciudad", "canal")

facturacionPorCiudadCanal.show(truncate = false)
// Out:
// +---------+-------+---------------+
// |ciudad   |canal  |total_facturado|
// +---------+-------+---------------+
// |NULL     |NULL   |7100.0         |
// |Barcelona|NULL   |1620.0         |
// |Barcelona|Airbnb |360.0          |
// |Barcelona|Booking|1260.0         |
// |Bilbao   |NULL   |875.0          |
// |Bilbao   |Airbnb |195.0          |
// |Bilbao   |Directo|680.0          |
// |Madrid   |NULL   |2725.0         |
// |Madrid   |Airbnb |1565.0         |
// |Madrid   |Booking|520.0          |
// |Madrid   |Directo|640.0          |
// |Sevilla  |NULL   |930.0          |
// |Sevilla  |Airbnb |550.0          |
// |Sevilla  |Booking|220.0          |
// |Sevilla  |Directo|160.0          |
// |Valencia |NULL   |950.0          |
// |Valencia |Airbnb |225.0          |
// |Valencia |Booking|365.0          |
// |Valencia |Directo|360.0          |
// +---------+-------+---------------+
// facturacionPorCiudadCanal: org.apache.spark.sql.Dataset[org.apache.spark.sql.Row] = [ciudad: string, canal: string ... 1 more field]

// %% [markdown]
// ---
//
// ### Pregunta 12 — ¿Podemos ver la facturación por ciudad y canal como una tabla cruzada?
//
// El equipo de operaciones prefiere ver los datos en formato tabla dinámica para comparar canales entre ciudades de un vistazo.
//
// **Lo que debes hacer:**
//
// 1. Usa `groupBy("ciudad").pivot("canal").agg(sum("ingreso_reserva"))`.
// 2. Ordena por `ciudad`.
// 3. Muestra el resultado.
//
// **Reflexión:** ¿Qué aparece como `null` en la tabla pivot y qué significa?

// %%
reservasAmpliado
    .groupBy("ciudad")
    .pivot("canal")
    .agg(sum("ingreso_reserva"))
    .show()

// para esa ciudad y ese canal no hay reservas
// Out:
// +---------+------+-------+-------+
// |   ciudad|Airbnb|Booking|Directo|
// +---------+------+-------+-------+
// |   Madrid|1565.0|  520.0|  640.0|
// |   Bilbao| 195.0|   NULL|  680.0|
// |Barcelona| 360.0| 1260.0|   NULL|
// | Valencia| 225.0|  365.0|  360.0|
// |  Sevilla| 550.0|  220.0|  160.0|
// +---------+------+-------+-------+

// %% [markdown]
// ---
//
// ## 🔗 PARTE 4 — Cruce de fuentes de datos (Joins)
//
// ### 📌 Sesión cubierta: Clase 18 Sesión 1

// %% [markdown]
// ---
//
// > 🔧 **Preparación:** Antes de esta sección, asegúrate de que los tres DataFrames base están cargados (`reservas`, `apartamentos`, `propietarios`) y de que existe la columna `ingreso_reserva` en `reservas`. Si `apartamentos` tiene una columna `ciudad`, renómbrala a `ciudad_apt` para evitar conflictos.
// >

// %%
reservasAmpliado.show()
val propietariosAmpliado = propietarios.withColumnRenamed("ciudad",  "ciudad_propietario")
propietariosAmpliado.show()
apartamentos.show()
// Out:
// +----------+--------------+-------------+------------+-------------+------------+-------+----------+---------+----------+---------------+
// |id_reserva|id_apartamento|fecha_entrada|fecha_salida|num_huespedes|precio_noche|  canal|valoracion|   ciudad|num_noches|ingreso_reserva|
// +----------+--------------+-------------+------------+-------------+------------+-------+----------+---------+----------+---------------+
// |      R001|        APT001|   2025-01-10|  2025-01-13|            2|        95.0| Airbnb|       4.8|   Madrid|         3|          285.0|
// |      R002|        APT002|   2025-01-12|  2025-01-15|            4|       120.0|Booking|       4.5|Barcelona|         3|          360.0|
// |      R003|        APT003|   2025-01-20|  2025-01-22|            1|        75.0|Directo|       5.0| Valencia|         2|          150.0|
// |      R004|        APT001|   2025-02-01|  2025-02-05|            3|        95.0| Airbnb|       4.7|   Madrid|         4|          380.0|
// |      R005|        APT004|   2025-02-10|  2025-02-12|            2|       110.0|Booking|       4.2|  Sevilla|         2|          220.0|
// |      R006|        APT002|   2025-02-14|  2025-02-17|            5|       120.0| Airbnb|       4.9|Barcelona|         3|          360.0|
// |      R007|        APT005|   2025-02-20|  2025-02-23|            2|        85.0|Directo|       4.6|   Bilbao|         3|          255.0|
// |      R008|        APT003|   2025-03-01|  2025-03-04|            1|        75.0|Booking|       4.4| Valencia|         3|          225.0|
// |      R009|        APT001|   2025-03-10|  2025-03-14|            4|        95.0| Airbnb|       4.8|   Madrid|         4|          380.0|
// |      R010|        APT006|   2025-03-15|  2025-03-17|            2|       130.0|Directo|       5.0|   Madrid|         2|          260.0|
// |      R011|        APT004|   2025-03-20|  2025-03-22|            3|       110.0| Airbnb|       4.3|  Sevilla|         2|          220.0|
// |      R012|        APT007|   2025-04-01|  2025-04-04|            2|        90.0|Booking|       4.5|Barcelona|         3|          270.0|
// |      R013|        APT005|   2025-04-08|  2025-04-10|            1|        85.0|Directo|       4.7|   Bilbao|         2|          170.0|
// |      R014|        APT006|   2025-04-12|  2025-04-16|            3|       130.0| Airbnb|       4.9|   Madrid|         4|          520.0|
// |      R015|        APT002|   2025-04-20|  2025-04-23|            4|       120.0|Booking|       4.6|Barcelona|         3|          360.0|
// |      R016|        APT008|   2025-05-01|  2025-05-04|            2|        70.0|Directo|       4.1| Valencia|         3|          210.0|
// |      R017|        APT003|   2025-05-10|  2025-05-13|            2|        75.0| Airbnb|       4.5| Valencia|         3|          225.0|
// |      R018|        APT007|   2025-05-15|  2025-05-18|            3|        90.0|Booking|       4.8|Barcelona|         3|          270.0|
// |      R019|        APT001|   2025-05-20|  2025-05-24|            2|        95.0|Directo|       5.0|   Madrid|         4|          380.0|
// |      R020|        APT009|   2025-05-25|  2025-05-28|            1|        65.0| Airbnb|       3.9|   Bilbao|         3|          195.0|
// +----------+--------------+-------------+------------+-------------+------------+-------+----------+---------+----------+---------------+
// only showing top 20 rows
// +----------------+------------------+----------------+-------------+--------------+-------------+
// |antiguedad_anios|ciudad_propietario|  especialidades|       nombre|propietario_id|tipo_contrato|
// +----------------+------------------+----------------+-------------+--------------+-------------+
// |               5|            Madrid| [Estudio, Piso]|Laura Sánchez|           P01|      Premium|
// |               3|         Barcelona|          [Piso]|Carlos Méndez|           P02|     Estándar|
// |               7|           Sevilla|   [Piso, Ático]|  Ana Ferrero|           P03|      Premium|
// |               2|            Bilbao|   [Ático, Piso]|  Javier Ruiz|           P04|     Estándar|
// |               6|          Valencia|[Estudio, Ático]|    Marta Gil|           P05|      Premium|
// +----------------+------------------+----------------+-------------+--------------+-------------+
//
// +--------------+-------+------------+----------------+-------------+--------------+------+
// |id_apartamento|   tipo|habitaciones|metros_cuadrados|tiene_parking|propietario_id|activo|
// +--------------+-------+------------+----------------+-------------+--------------+------+
// |        APT001|Estudio|           1|              35|        false|           P01|  true|
// |        APT002|   Piso|           3|              85|         true|           P02|  true|
// |        APT003|Estudio|           1|              30|        false|           P01|  true|
// |        APT004|   Piso|           2|              65|         true|           P03|  true|
// |        APT005|  Ático|           2|              70|         true|           P04|  true|
// |        APT006|   Piso|           3|              90|         true|           P02|  true|
// |        APT007|Estudio|           1|              28|        false|           P05|  true|
// |        APT008|Estudio|           1|              32|        false|           P03| false|
// |        APT009|   Piso|           2|              55|        false|           P04|  true|
// |        APT010|  Ático|           3|             100|         true|           P05|  true|
// +--------------+-------+------------+----------------+-------------+--------------+------+
// propietariosAmpliado: org.apache.spark.sql.package.DataFrame = [antiguedad_anios: bigint, ciudad_propietario: string ... 4 more fields]

// %% [markdown]
// ---
//
// ### Pregunta 13 — ¿Cuántas noches y a qué precio se ha alquilado cada apartamento?
//
// El equipo de producto quiere enriquecer el historial de reservas con información del apartamento (tipo, habitaciones, metros).
//
// **Lo que debes hacer:**
//
// 1. Renombra la columna `activo` de `apartamentos` a `apt_activo` para evitar ambigüedades.
// 2. Haz un **INNER JOIN** entre `reservas` y `apartamentos` usando `id_apartamento` como clave.
// 3. Selecciona: `id_reserva`, `ciudad` (de reservas), `tipo`, `habitaciones`, `metros_cuadrados`, `precio_noche`, `ingreso_reserva`.
// 4. Ordena por `ingreso_reserva` descendente.
// 5. ¿Cuántas filas tiene el resultado? ¿Se pierde alguna reserva?

// %%
val apartamentosRenombrado = apartamentos.withColumnRenamed("activo", "apt_activo")

val reservasConApartamentos = reservasAmpliado
    .join(apartamentosRenombrado, "id_apartamento", "inner")
    .select("id_reserva", "ciudad", "tipo", "habitaciones", "metros_cuadrados", "precio_noche", "ingreso_reserva")
    .orderBy($"ingreso_reserva".desc)

reservasConApartamentos.show(truncate = false)
println(s"Filas resultado: ${reservasConApartamentos.count()}")
println(s"Reservas originales: ${reservas.count()}")
// Out:
// +----------+---------+-------+------------+----------------+------------+---------------+
// |id_reserva|ciudad   |tipo   |habitaciones|metros_cuadrados|precio_noche|ingreso_reserva|
// +----------+---------+-------+------------+----------------+------------+---------------+
// |R014      |Madrid   |Piso   |3           |90              |130.0       |520.0          |
// |R021      |Madrid   |Piso   |3           |90              |130.0       |520.0          |
// |R004      |Madrid   |Estudio|1           |35              |95.0        |380.0          |
// |R009      |Madrid   |Estudio|1           |35              |95.0        |380.0          |
// |R019      |Madrid   |Estudio|1           |35              |95.0        |380.0          |
// |R002      |Barcelona|Piso   |3           |85              |120.0       |360.0          |
// |R006      |Barcelona|Piso   |3           |85              |120.0       |360.0          |
// |R015      |Barcelona|Piso   |3           |85              |120.0       |360.0          |
// |R023      |Sevilla  |Piso   |2           |65              |110.0       |330.0          |
// |R001      |Madrid   |Estudio|1           |35              |95.0        |285.0          |
// |R012      |Barcelona|Estudio|1           |28              |90.0        |270.0          |
// |R018      |Barcelona|Estudio|1           |28              |90.0        |270.0          |
// |R010      |Madrid   |Piso   |3           |90              |130.0       |260.0          |
// |R007      |Bilbao   |Ático  |2           |70              |85.0        |255.0          |
// |R025      |Bilbao   |Ático  |2           |70              |85.0        |255.0          |
// |R008      |Valencia |Estudio|1           |30              |75.0        |225.0          |
// |R017      |Valencia |Estudio|1           |30              |75.0        |225.0          |
// |R005      |Sevilla  |Piso   |2           |65              |110.0       |220.0          |
// |R011      |Sevilla  |Piso   |2           |65              |110.0       |220.0          |
// |R016      |Valencia |Estudio|1           |32              |70.0        |210.0          |
// +----------+---------+-------+------------+----------------+------------+---------------+
// only showing top 20 rows
// Filas resultado: 25
// Reservas originales: 25
// apartamentosRenombrado: org.apache.spark.sql.package.DataFrame = [id_apartamento: string, tipo: string ... 5 more fields]
// reservasConApartamentos: org.apache.spark.sql.Dataset[org.apache.spark.sql.Row] = [id_reserva: string, ciudad: string ... 5 more fields]

// %% [markdown]
// ---
//
// ### Pregunta 14 — ¿Hay apartamentos que nunca han tenido ninguna reserva?
//
// El equipo de negocio necesita identificar activos improductivos para renegociar contratos con propietarios.
//
// **Lo que debes hacer:**
//
// 1. Haz un **LEFT JOIN** entre `apartamentos` y `reservas` usando `id_apartamento` como clave.
// 2. Filtra las filas donde `id_reserva` sea `null` (estos son los apartamentos sin reservas).
// 3. Selecciona `id_apartamento`, `tipo`, `habitaciones`, `propietario_id`.
// 4. Muestra el resultado.
//
// **Reflexión:** ¿Qué tipo de join usarías si en cambio quisieras ver todas las reservas aunque el apartamento ya no exista en el catálogo?

// %%
val apartamentosSinReservas = apartamentos
    // .join(reservas, "id_apartamento" , "id_apartamento", "left")
    .join(reservas.select("id_reserva", "id_apartamento"), "id_apartamento", "left")
    .filter($"id_reserva".isNull)
    .select("id_apartamento", "tipo", "habitaciones", "propietario_id")

apartamentosSinReservas.show(truncate = false)

//RIGHT
// Out:
// +--------------+----+------------+--------------+
// |id_apartamento|tipo|habitaciones|propietario_id|
// +--------------+----+------------+--------------+
// +--------------+----+------------+--------------+
// apartamentosSinReservas: org.apache.spark.sql.package.DataFrame = [id_apartamento: string, tipo: string ... 2 more fields]

// %% [markdown]
// ---
//
// ### Pregunta 15 — ¿Qué propietarios tienen al menos un apartamento con reservas activas?
//
// El departamento legal necesita contactar a los propietarios activos para renovar contratos.
//
// **Lo que debes hacer:**
//
// 1. Haz un **LEFT SEMI JOIN** entre `propietarios` y `apartamentos` usando `propietario_id` como clave.
// 2. Muestra solo las columnas de `propietarios`: `propietario_id`, `nombre`, `tipo_contrato`.

// %%
val propietariosActivos = propietarios
    .join(apartamentos, "propietario_id", "semi")
    .select("propietario_id", "nombre", "tipo_contrato")

propietariosActivos.show(truncate = false)
// Out:
// +--------------+-------------+-------------+
// |propietario_id|nombre       |tipo_contrato|
// +--------------+-------------+-------------+
// |P01           |Laura Sánchez|Premium      |
// |P02           |Carlos Méndez|Estándar     |
// |P03           |Ana Ferrero  |Premium      |
// |P04           |Javier Ruiz  |Estándar     |
// |P05           |Marta Gil    |Premium      |
// +--------------+-------------+-------------+
// propietariosActivos: org.apache.spark.sql.package.DataFrame = [propietario_id: string, nombre: string ... 1 more field]

// %% [markdown]
// ---
//
// ### Pregunta 16 — ¿Qué propietarios no tienen ningún apartamento en el catálogo actual?
//
// **Lo que debes hacer:**
//
// 1. Haz un **LEFT ANTI JOIN** entre `propietarios` y `apartamentos` usando `propietario_id` como clave.
// 2. Muestra `propietario_id`, `nombre`, `ciudad`.

// %%
val propietariosNoActivos = propietarios
    .join(apartamentos, "propietario_id", "anti")
    .select("propietario_id", "nombre", "tipo_contrato")

propietariosNoActivos.show(truncate = false)
// Out:
// +--------------+------+-------------+
// |propietario_id|nombre|tipo_contrato|
// +--------------+------+-------------+
// +--------------+------+-------------+
// propietariosNoActivos: org.apache.spark.sql.package.DataFrame = [propietario_id: string, nombre: string ... 1 more field]

// %% [markdown]
// ---
//
// ### Pregunta 17 — ¿Cuál es el informe completo de reservas con datos de apartamento y propietario?
//
// El equipo directivo quiere un informe consolidado que cruce las tres fuentes.
//
// **Lo que debes hacer:**
//
// 1. Empieza por el INNER JOIN de `reservas` con `apartamentos` (Pregunta 13, renombrando columnas ambiguas antes).
// 2. Encadena un segundo JOIN (tipo `inner`) con `propietarios` usando `propietario_id`.
// 3. Selecciona: `id_reserva`, `ciudad` (reservas), `tipo`, `habitaciones`, `nombre` (propietario), `tipo_contrato`, `ingreso_reserva`.
// 4. Ordena por `ingreso_reserva` descendente.

// %%
val informeReservas = reservasAmpliado
    .withColumnRenamed("ciudad", "ciudad_reserva")
    .join(apartamentos, "id_apartamento", "inner")
    .join(propietarios, "propietario_id", "inner")
    .withColumnRenamed("nombre", "nombre_propietario")
    .select("id_reserva", "ciudad_reserva", "tipo", "habitaciones", "nombre_propietario", "tipo_contrato", "ingreso_reserva")
    .orderBy($"ingreso_reserva".desc)

informeReservas.show(truncate=false)
// Out:
// +----------+--------------+-------+------------+------------------+-------------+---------------+
// |id_reserva|ciudad_reserva|tipo   |habitaciones|nombre_propietario|tipo_contrato|ingreso_reserva|
// +----------+--------------+-------+------------+------------------+-------------+---------------+
// |R014      |Madrid        |Piso   |3           |Carlos Méndez     |Estándar     |520.0          |
// |R021      |Madrid        |Piso   |3           |Carlos Méndez     |Estándar     |520.0          |
// |R004      |Madrid        |Estudio|1           |Laura Sánchez     |Premium      |380.0          |
// |R009      |Madrid        |Estudio|1           |Laura Sánchez     |Premium      |380.0          |
// |R019      |Madrid        |Estudio|1           |Laura Sánchez     |Premium      |380.0          |
// |R002      |Barcelona     |Piso   |3           |Carlos Méndez     |Estándar     |360.0          |
// |R006      |Barcelona     |Piso   |3           |Carlos Méndez     |Estándar     |360.0          |
// |R015      |Barcelona     |Piso   |3           |Carlos Méndez     |Estándar     |360.0          |
// |R023      |Sevilla       |Piso   |2           |Ana Ferrero       |Premium      |330.0          |
// |R001      |Madrid        |Estudio|1           |Laura Sánchez     |Premium      |285.0          |
// |R012      |Barcelona     |Estudio|1           |Marta Gil         |Premium      |270.0          |
// |R018      |Barcelona     |Estudio|1           |Marta Gil         |Premium      |270.0          |
// |R010      |Madrid        |Piso   |3           |Carlos Méndez     |Estándar     |260.0          |
// |R007      |Bilbao        |Ático  |2           |Javier Ruiz       |Estándar     |255.0          |
// |R025      |Bilbao        |Ático  |2           |Javier Ruiz       |Estándar     |255.0          |
// |R008      |Valencia      |Estudio|1           |Laura Sánchez     |Premium      |225.0          |
// |R017      |Valencia      |Estudio|1           |Laura Sánchez     |Premium      |225.0          |
// |R005      |Sevilla       |Piso   |2           |Ana Ferrero       |Premium      |220.0          |
// |R011      |Sevilla       |Piso   |2           |Ana Ferrero       |Premium      |220.0          |
// |R016      |Valencia      |Estudio|1           |Ana Ferrero       |Premium      |210.0          |
// +----------+--------------+-------+------------+------------------+-------------+---------------+
// only showing top 20 rows
// informeReservas: org.apache.spark.sql.Dataset[org.apache.spark.sql.Row] = [id_reserva: string, ciudad_reserva: string ... 5 more fields]

// %% [markdown]
// ---
//
// ### Pregunta 18 — ¿Tiene sentido aplicar broadcast en alguno de estos joins?
//
// El equipo técnico quiere documentar las decisiones de optimización.
//
// **Lo que debes hacer:**
//
// 1. Repite el JOIN de `reservas` con `apartamentos` **con** `broadcast(apartamentos)`.
// 2. Ejecuta `.explain()` sobre ambas versiones (sin broadcast y con broadcast).
// 3. Responde en una celda Markdown:
//     - ¿Qué tipo de join aparece en el plan sin broadcast?
//     - ¿Qué tipo de join aparece en el plan con broadcast?
//     - ¿Por qué tiene sentido hacer broadcast sobre `apartamentos` y no sobre `reservas`?

// %%
val reservasConBroadcastApartamentos = reservasAmpliado
    .join(broadcast(apartamentosRenombrado), "id_apartamento", "inner")
    .select("id_reserva", "ciudad", "tipo", "habitaciones", "metros_cuadrados", "precio_noche", "ingreso_reserva")
    .orderBy($"ingreso_reserva".desc)

reservasConApartamentos.explain()
reservasConBroadcastApartamentos.explain()

// en ambos casos aparece BroadcastHashJoin 
// Broadcast sobre apartamentos porque más o menos son fijos, crecen muy despacio
// pero sobre las reservas no, puesto que crecen mucho más que los apartamentos
// Out:
// == Physical Plan ==
// AdaptiveSparkPlan isFinalPlan=false
// +- Sort [ingreso_reserva#491 DESC NULLS LAST], true, 0
//    +- Exchange rangepartitioning(ingreso_reserva#491 DESC NULLS LAST, 4), ENSURE_REQUIREMENTS, [plan_id=1830]
//       +- Project [id_reserva#336, ciudad#344, tipo#401, habitaciones#402, metros_cuadrados#403, precio_noche#341, ingreso_reserva#491]
//          +- BroadcastHashJoin [id_apartamento#337], [id_apartamento#400], Inner, BuildRight, false
//             :- Project [id_reserva#336, id_apartamento#337, precio_noche#341, ciudad#344, (cast(datediff(fecha_salida#339, fecha_entrada#338) as double) * precio_noche#341) AS ingreso_reserva#491]
//             :  +- Filter isnotnull(id_apartamento#337)
//             :     +- FileScan csv [id_reserva#336,id_apartamento#337,fecha_entrada#338,fecha_salida#339,precio_noche#341,ciudad#344] Batched: false, DataFilters: [isnotnull(id_apartamento#337)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/home/jovyan/work/curso_scala/@Examenes/datos/UrbanRent/reservas...., PartitionFilters: [], PushedFilters: [IsNotNull(id_apartamento)], ReadSchema: struct<id_reserva:string,id_apartamento:string,fecha_entrada:date,fecha_salida:date,precio_noche:...
//             +- BroadcastExchange HashedRelationBroadcastMode(List(input[0, string, false]),false), [plan_id=1826]
//                +- Filter isnotnull(id_apartamento#400)
//                   +- FileScan csv [id_apartamento#400,tipo#401,habitaciones#402,metros_cuadrados#403] Batched: false, DataFilters: [isnotnull(id_apartamento#400)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/home/jovyan/work/curso_scala/@Examenes/datos/UrbanRent/apartamen..., PartitionFilters: [], PushedFilters: [IsNotNull(id_apartamento)], ReadSchema: struct<id_apartamento:string,tipo:string,habitaciones:int,metros_cuadrados:int>
//
//
// == Physical Plan ==
// AdaptiveSparkPlan isFinalPlan=false
// +- Sort [ingreso_reserva#491 DESC NULLS LAST], true, 0
//    +- Exchange rangepartitioning(ingreso_reserva#491 DESC NULLS LAST, 4), ENSURE_REQUIREMENTS, [plan_id=1867]
//       +- Project [id_reserva#336, ciudad#344, tipo#401, habitaciones#402, metros_cuadrados#403, precio_noche#341, ingreso_reserva#491]
//          +- BroadcastHashJoin [id_apartamento#337], [id_apartamento#400], Inner, BuildRight, false
//             :- Project [id_reserva#336, id_apartamento#337, precio_noche#341, ciudad#344, (cast(datediff(fecha_salida#339, fecha_entrada#338) as double) * precio_noche#341) AS ingreso_reserva#491]
//             :  +- Filter isnotnull(id_apartamento#337)
//             :     +- FileScan csv [id_reserva#336,id_apartamento#337,fecha_entrada#338,fecha_salida#339,precio_noche#341,ciudad#344] Batched: false, DataFilters: [isnotnull(id_apartamento#337)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/home/jovyan/work/curso_scala/@Examenes/datos/UrbanRent/reservas...., PartitionFilters: [], PushedFilters: [IsNotNull(id_apartamento)], ReadSchema: struct<id_reserva:string,id_apartamento:string,fecha_entrada:date,fecha_salida:date,precio_noche:...
//             +- BroadcastExchange HashedRelationBroadcastMode(List(input[0, string, false]),false), [plan_id=1863]
//                +- Filter isnotnull(id_apartamento#400)
//                   +- FileScan csv [id_apartamento#400,tipo#401,habitaciones#402,metros_cuadrados#403] Batched: false, DataFilters: [isnotnull(id_apartamento#400)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/home/jovyan/work/curso_scala/@Examenes/datos/UrbanRent/apartamen..., PartitionFilters: [], PushedFilters: [IsNotNull(id_apartamento)], ReadSchema: struct<id_apartamento:string,tipo:string,habitaciones:int,metros_cuadrados:int>
// reservasConBroadcastApartamentos: org.apache.spark.sql.Dataset[org.apache.spark.sql.Row] = [id_reserva: string, ciudad: string ... 5 more fields]

// %% [markdown]
// ---
//
// ## 🔠 PARTE 5 — Funciones integradas y UDFs
//
// ### 📌 Sesión cubierta: Clase 19 Sesión 1

// %% [markdown]
// ---
//
// ### Pregunta 19 — ¿Cómo podemos presentar las fechas de entrada en formato europeo?
//
// El equipo de atención al cliente necesita las fechas en formato `dd/MM/yyyy` para los informes que envían a los propietarios.
//
// **Lo que debes hacer:**
//
// 1. Sobre `reservas`, añade la columna `fecha_entrada_es` usando `date_format($"fecha_entrada", "dd/MM/yyyy")`.
// 2. Añade también `mes_entrada` = `month($"fecha_entrada")` y `anio_entrada` = `year($"fecha_entrada")`.
// 3. Selecciona `id_reserva`, `ciudad`, `fecha_entrada`, `fecha_entrada_es`, `mes_entrada`, `anio_entrada`.
// 4. Muestra las primeras 6 filas.

// %%
reservas
    .select(
        col("id_reserva"),
        col("ciudad"),
        col("fecha_entrada"),
        date_format($"fecha_entrada", "dd/MM/yyyy").as("fecha_entrada_es"),
        month($"fecha_entrada").as("mes_entrada"),
        year($"fecha_entrada").as("anio_entrada")
    )
    .show(6)
// Out:
// +----------+---------+-------------+----------------+-----------+------------+
// |id_reserva|   ciudad|fecha_entrada|fecha_entrada_es|mes_entrada|anio_entrada|
// +----------+---------+-------------+----------------+-----------+------------+
// |      R001|   Madrid|   2025-01-10|      10/01/2025|          1|        2025|
// |      R002|Barcelona|   2025-01-12|      12/01/2025|          1|        2025|
// |      R003| Valencia|   2025-01-20|      20/01/2025|          1|        2025|
// |      R004|   Madrid|   2025-02-01|      01/02/2025|          2|        2025|
// |      R005|  Sevilla|   2025-02-10|      10/02/2025|          2|        2025|
// |      R006|Barcelona|   2025-02-14|      14/02/2025|          2|        2025|
// +----------+---------+-------------+----------------+-----------+------------+
// only showing top 6 rows

// %% [markdown]
// ---
//
// ### Pregunta 20 — ¿Cuántos días de antelación se hacen las reservas respecto a una fecha de referencia?
//
// Supon que hoy es `2025-01-01` (fecha de referencia fija para que el resultado sea reproducible).
//
// **Lo que debes hacer:**
//
// 1. Define una columna `fecha_ref` = `to_date(lit("2025-01-01"), "yyyy-MM-dd")`.
// 2. Calcula `dias_antelacion` = `datediff($"fecha_entrada", $"fecha_ref")`.
// 3. Selecciona `id_reserva`, `ciudad`, `fecha_entrada`, `dias_antelacion`.
// 4. Ordena por `dias_antelacion` ascendente (las reservas más próximas primero).

// %%
val fechaRef = to_date(lit("2025-01-01"), "yyyy-MM-dd")

println(fechaRef)

reservas
	.withColumn("fecha_ref", fechaRef)
	.withColumn("dias_antelacion", datediff($"fecha_entrada", $"fecha_ref"))
	.select("id_reserva", "ciudad", "fecha_entrada", "dias_antelacion")
	.orderBy($"dias_antelacion".asc)
	.show(false)
// Out:
// to_date('2025-01-01', 'yyyy-MM-dd')
// +----------+---------+-------------+---------------+
// |id_reserva|ciudad   |fecha_entrada|dias_antelacion|
// +----------+---------+-------------+---------------+
// |R001      |Madrid   |2025-01-10   |9              |
// |R002      |Barcelona|2025-01-12   |11             |
// |R003      |Valencia |2025-01-20   |19             |
// |R004      |Madrid   |2025-02-01   |31             |
// |R005      |Sevilla  |2025-02-10   |40             |
// |R006      |Barcelona|2025-02-14   |44             |
// |R007      |Bilbao   |2025-02-20   |50             |
// |R008      |Valencia |2025-03-01   |59             |
// |R009      |Madrid   |2025-03-10   |68             |
// |R010      |Madrid   |2025-03-15   |73             |
// |R011      |Sevilla  |2025-03-20   |78             |
// |R012      |Barcelona|2025-04-01   |90             |
// |R013      |Bilbao   |2025-04-08   |97             |
// |R014      |Madrid   |2025-04-12   |101            |
// |R015      |Barcelona|2025-04-20   |109            |
// |R016      |Valencia |2025-05-01   |120            |
// |R017      |Valencia |2025-05-10   |129            |
// |R018      |Barcelona|2025-05-15   |134            |
// |R019      |Madrid   |2025-05-20   |139            |
// |R020      |Bilbao   |2025-05-25   |144            |
// +----------+---------+-------------+---------------+
// only showing top 20 rows
// fechaRef: org.apache.spark.sql.Column = to_date('2025-01-01', 'yyyy-MM-dd')

// %% [markdown]
// ---
//
// ### Pregunta 21 — ¿Están bien formateados los IDs de reserva? ¿Podemos estandarizarlos?
//
// El sistema legado generó algunos IDs con espacios o en minúsculas. Aplica limpieza estándar.
//
// **Lo que debes hacer:**
//
// 1. Simula datos sucios añadiendo una columna `id_reserva_sucio` con: `concat($"id_reserva", lit(" "))` (añade un espacio al final).
// 2. Limpia esa columna con `trim()` y ponla en mayúsculas con `upper()`. Guarda el resultado como `id_reserva_limpio`.
// 3. Añade también una columna `ciudad_normalizada` = `initcap($"ciudad")`.
// 4. Selecciona las tres versiones para comparar: `id_reserva_sucio`, `id_reserva_limpio`, `ciudad`, `ciudad_normalizada`.
// 5. Muestra las primeras 5 filas.

// %%
val reservasIdsEstandarizados = reservas
    .withColumn("id_reserva_sucio", concat($"id_reserva", lit(" ")))
    .withColumn("id_reserva_limpio", upper(trim($"id_reserva_sucio")))
    .withColumn("ciudad_normalizada", initcap($"ciudad"))
    .select("id_reserva_sucio", "id_reserva_limpio", "ciudad", "ciudad_normalizada")

reservasIdsEstandarizados.show(5, false)
// Out:
// +----------------+-----------------+---------+------------------+
// |id_reserva_sucio|id_reserva_limpio|ciudad   |ciudad_normalizada|
// +----------------+-----------------+---------+------------------+
// |R001            |R001             |Madrid   |Madrid            |
// |R002            |R002             |Barcelona|Barcelona         |
// |R003            |R003             |Valencia |Valencia          |
// |R004            |R004             |Madrid   |Madrid            |
// |R005            |R005             |Sevilla  |Sevilla           |
// +----------------+-----------------+---------+------------------+
// only showing top 5 rows
// reservasIdsEstandarizados: org.apache.spark.sql.package.DataFrame = [id_reserva_sucio: string, id_reserva_limpio: string ... 2 more fields]

// %% [markdown]
// ---
//
// ### Pregunta 22 — ¿Qué especialidades tienen registradas los propietarios?
//
// El JSON de propietarios incluye un array `especialidades` por propietario. El equipo quiere analizar estas especialidades a nivel de fila individual.
//
// **Lo que debes hacer:**
//
// 1. Sobre `propietarios`, usa `explode($"especialidades")` para expandir el array en una fila por especialidad. Llama a la nueva columna `especialidad`.
// 2. Selecciona `propietario_id`, `nombre`, `especialidad`.
// 3. Muestra el resultado.
// 4. ¿Cuántas filas tiene el resultado después del explode?
// 5. Cuenta cuántos propietarios tienen cada `especialidad` usando `groupBy("especialidad").count()`. Ordena de mayor a menor.

// %%
val especialidadesPropietarios = propietarios
    .select(
        $"propietario_id",
        $"nombre",
        explode($"especialidades").as("especialidad")
    )

especialidadesPropietarios.show(false)

println(s"Filas tras explode: ${especialidadesPropietarios.count()}")

val conteoEspecialidades = especialidadesPropietarios
    .groupBy("especialidad")
    .count()
    .orderBy($"count".desc)

conteoEspecialidades.show(false)
// Out:
// +--------------+-------------+------------+
// |propietario_id|nombre       |especialidad|
// +--------------+-------------+------------+
// |P01           |Laura Sánchez|Estudio     |
// |P01           |Laura Sánchez|Piso        |
// |P02           |Carlos Méndez|Piso        |
// |P03           |Ana Ferrero  |Piso        |
// |P03           |Ana Ferrero  |Ático       |
// |P04           |Javier Ruiz  |Ático       |
// |P04           |Javier Ruiz  |Piso        |
// |P05           |Marta Gil    |Estudio     |
// |P05           |Marta Gil    |Ático       |
// +--------------+-------------+------------+
//
// Filas tras explode: 9
// +------------+-----+
// |especialidad|count|
// +------------+-----+
// |Piso        |4    |
// |Ático       |3    |
// |Estudio     |2    |
// +------------+-----+
// especialidadesPropietarios: org.apache.spark.sql.package.DataFrame = [propietario_id: string, nombre: string ... 1 more field]
// conteoEspecialidades: org.apache.spark.sql.Dataset[org.apache.spark.sql.Row] = [especialidad: string, count: bigint]

// %% [markdown]
// ---
//
// ### Pregunta 23 — ¿Cómo clasificamos la calidad de cada reserva según su valoración?
//
// El equipo de calidad necesita una categorización automática para filtrar reservas en los informes.
//
// **Lo que debes hacer:**
//
// 1. Crea una UDF llamada `clasificarCalidadUDF` que reciba `valoracion: java.lang.Double` y devuelva:
//
//
//     | Condición | Categoría |
//     | --- | --- |
//     | `null` | `"Sin valoración"` |
//     | `>= 4.8` | `"Excelente"` |
//     | `>= 4.5` | `"Muy buena"` |
//     | `>= 4.0` | `"Buena"` |
//     | cualquier otro | `"Mejorable"` |
// 2. Aplica la UDF sobre la columna `valoracion` del DataFrame `reservas` y añade la columna `calidad_reserva`.
// 3. Registra la UDF en Spark SQL con `spark.udf.register("clasificar_calidad", clasificarCalidadUDF)`.
// 4. Selecciona `id_reserva`, `ciudad`, `valoracion`, `calidad_reserva` y muestra el resultado completo.
// 5. Agrupa por `calidad_reserva` y cuenta cuántas reservas caen en cada categoría. Ordena de mayor a menor.

// %%
val clasificarCalidadUDF = udf((valoracion: java.lang.Double) => {
    if      (valoracion == null) "Sin valoración"
    else if (valoracion >= 4.8) "Excelente"
    else if (valoracion >= 4.5) "Muy buena"
    else if (valoracion >= 4.0) "Buena"
    else "Mejorable"
})

spark.udf.register("clasificar_calidad", clasificarCalidadUDF)

val reservasConCalidad = reservas
    .withColumn("calidad_reserva", clasificarCalidadUDF($"valoracion"))

reservasConCalidad
    .select("id_reserva", "ciudad", "valoracion", "calidad_reserva")
    .show(truncate = false)

reservasConCalidad
    .groupBy("calidad_reserva")
    .count()
    .orderBy($"count".desc)
    .show(truncate = false)
// Out:
// +----------+---------+----------+---------------+
// |id_reserva|ciudad   |valoracion|calidad_reserva|
// +----------+---------+----------+---------------+
// |R001      |Madrid   |4.8       |Excelente      |
// |R002      |Barcelona|4.5       |Muy buena      |
// |R003      |Valencia |5.0       |Excelente      |
// |R004      |Madrid   |4.7       |Muy buena      |
// |R005      |Sevilla  |4.2       |Buena          |
// |R006      |Barcelona|4.9       |Excelente      |
// |R007      |Bilbao   |4.6       |Muy buena      |
// |R008      |Valencia |4.4       |Buena          |
// |R009      |Madrid   |4.8       |Excelente      |
// |R010      |Madrid   |5.0       |Excelente      |
// |R011      |Sevilla  |4.3       |Buena          |
// |R012      |Barcelona|4.5       |Muy buena      |
// |R013      |Bilbao   |4.7       |Muy buena      |
// |R014      |Madrid   |4.9       |Excelente      |
// |R015      |Barcelona|4.6       |Muy buena      |
// |R016      |Valencia |4.1       |Buena          |
// |R017      |Valencia |4.5       |Muy buena      |
// |R018      |Barcelona|4.8       |Excelente      |
// |R019      |Madrid   |5.0       |Excelente      |
// |R020      |Bilbao   |3.9       |Mejorable      |
// +----------+---------+----------+---------------+
// only showing top 20 rows
// +---------------+-----+
// |calidad_reserva|count|
// +---------------+-----+
// |Excelente      |9    |
// |Muy buena      |9    |
// |Buena          |6    |
// |Mejorable      |1    |
// +---------------+-----+
// clasificarCalidadUDF: org.apache.spark.sql.expressions.UserDefinedFunction = SparkUserDefinedFunction(
//   f = ammonite.$sess.cmd38$Helper$$Lambda$8919/0x00007e6979c28dd8@10268e11,
//   dataType = StringType,
//   inputEncoders = ArraySeq(Some(value = BoxedDoubleEncoder)),
//   outputEncoder = Some(value = StringEncoder),
//   givenName = None,
//   nullable = true,
//   deterministic = true
// )
// res38_1: org.apache.spark.sql.expressions.UserDefinedFunction = SparkUserDefinedFunction(
//   f = ammonite.$sess.cmd38$Helper$$Lambda$8919/0x00007e6979c28dd8@10268e11,
//   dataType = StringType,
//   inputEncoders = ArraySeq(Some(value = BoxedDoubleEncoder)),
//   outputEncoder = Some(value = StringEncoder),
//   givenName = Some(value = "clasificar_calidad"),
//   nullable = true,
//   deterministic = true
// )
// reservasConCalidad: org.apache.spark.sql.package.DataFrame = [id_reserva: string, id_apartamento: string ... 8 more fields]

// %% [markdown]
// ---
//
// ### Pregunta 24 — Informe final consolidado con Spark SQL
//
// Registra el DataFrame de reservas enriquecidas (con `ingreso_reserva`, `calidad_reserva`, `mes_entrada`) como vista temporal y ejecuta la siguiente consulta SQL para producir el informe de cierre.
//
// **Lo que debes hacer:**
//
// 1. Sobre el DataFrame `reservas` añade las columnas `ingreso_reserva`, `calidad_reserva` y `mes_entrada` (si no existen ya).
// 2. Regístralo como vista temporal: `reservasEnriquecidas.createOrReplaceTempView("reservas_enriquecidas")`.
// 3. Ejecuta esta consulta con `spark.sql(...)`:
//
//     ```sql
//     SELECT
//       ciudad,
//       canal,
//       COUNT(*) AS num_reservas,
//       ROUND(SUM(ingreso_reserva), 2) AS ingreso_total,
//       ROUND(AVG(valoracion), 2) AS valoracion_media,
//       clasificar_calidad(AVG(valoracion)) AS calidad_media
//     FROM reservas_enriquecidas
//     GROUP BY ciudad, canal
//     ORDER BY ingreso_total DESC
//     ```
//
// 4. Muestra el resultado.

// %%
val reservasEnriquecidas = reservas
    .withColumn("num_noches", datediff($"fecha_salida", $"fecha_entrada"))
    .withColumn("ingreso_reserva", $"num_noches" * $"precio_noche")
    .withColumn("calidad_reserva", clasificarCalidadUDF($"valoracion"))
    .withColumn("mes_entrada", month($"fecha_entrada"))

reservasEnriquecidas.createOrReplaceTempView("reservas_enriquecidas")

val informeFinal = spark.sql("""
    SELECT
        ciudad,
        canal,
        COUNT(*) AS num_reservas,
        ROUND(SUM(ingreso_reserva), 2) AS ingreso_total,
        ROUND(AVG(valoracion), 2) AS valoracion_media,
        clasificar_calidad(AVG(valoracion)) AS calidad_media
    FROM reservas_enriquecidas
    GROUP BY ciudad, canal
    ORDER BY ingreso_total DESC
""")

informeFinal.show(truncate = false)
// Out:
// +---------+-------+------------+-------------+----------------+-------------+
// |ciudad   |canal  |num_reservas|ingreso_total|valoracion_media|calidad_media|
// +---------+-------+------------+-------------+----------------+-------------+
// |Madrid   |Airbnb |4           |1565.0       |4.8             |Excelente    |
// |Barcelona|Booking|4           |1260.0       |4.6             |Muy buena    |
// |Bilbao   |Directo|3           |680.0        |4.7             |Muy buena    |
// |Madrid   |Directo|2           |640.0        |5.0             |Excelente    |
// |Sevilla  |Airbnb |2           |550.0        |4.45            |Buena        |
// |Madrid   |Booking|1           |520.0        |4.7             |Muy buena    |
// |Valencia |Booking|2           |365.0        |4.3             |Buena        |
// |Barcelona|Airbnb |1           |360.0        |4.9             |Excelente    |
// |Valencia |Directo|2           |360.0        |4.55            |Muy buena    |
// |Valencia |Airbnb |1           |225.0        |4.5             |Muy buena    |
// |Sevilla  |Booking|1           |220.0        |4.2             |Buena        |
// |Bilbao   |Airbnb |1           |195.0        |3.9             |Mejorable    |
// |Sevilla  |Directo|1           |160.0        |4.3             |Buena        |
// +---------+-------+------------+-------------+----------------+-------------+
// reservasEnriquecidas: org.apache.spark.sql.package.DataFrame = [id_reserva: string, id_apartamento: string ... 11 more fields]
// informeFinal: org.apache.spark.sql.package.DataFrame = [ciudad: string, canal: string ... 4 more fields]

// %% [markdown]
// ---
//
// ## ✅ Verificación final
//
// Ejecuta esta celda al finalizar para validar los resultados clave del caso de estudio.

// %%
println("=" * 60)
println("VERIFICACIÓN FINAL — Caso de Estudio UrbanRent Analytics")
println("=" * 60)

// Ajusta los nombres de variable a los que hayas usado en tu solución
val comprobaciones = Seq(
  ("P1  — Total reservas cargadas (25)",                  reservas.count() == 25),
  ("P3  — Apartamentos activos (9)",                      apartamentos.filter($"activo" === true).count() == 9),
  ("P4  — Reservas largas > 3 noches",                    reservasLargas.count() > 0),
  ("P8  — Ciudades en el ranking de ingresos (5)",        reservas.select("ciudad").distinct().count() == 5),
  ("P13 — INNER JOIN reservas × apartamentos (25 filas)", reservas.join(apartamentos, "id_apartamento").count() == 25),
  ("P22 — Explode especialidades propietarios (> 5 filas)", propietarios.select(explode($"especialidades")).count() >= 5)
)

comprobaciones.foreach { case (desc, ok) =>
  println(s"${if (ok) "✅ CORRECTO" else "❌ REVISAR"} — $desc")
}
// Out:
// ============================================================
// VERIFICACIÓN FINAL — Caso de Estudio UrbanRent Analytics
// ============================================================
// ✅ CORRECTO — P1  — Total reservas cargadas (25)
// ✅ CORRECTO — P3  — Apartamentos activos (9)
// ✅ CORRECTO — P4  — Reservas largas > 3 noches
// ✅ CORRECTO — P8  — Ciudades en el ranking de ingresos (5)
// ✅ CORRECTO — P13 — INNER JOIN reservas × apartamentos (25 filas)
// ✅ CORRECTO — P22 — Explode especialidades propietarios (> 5 filas)
// comprobaciones: Seq[(String, Boolean)] = List(
//   ("P1  — Total reservas cargadas (25)", true),
//   ("P3  — Apartamentos activos (9)", true),
//   ("P4  — Reservas largas > 3 noches", true),
//   ("P8  — Ciudades en el ranking de ingresos (5)", true),
//   ("P13 — INNER JOIN reservas × apartamentos (25 filas)", true),
//   ("P22 — Explode especialidades propietarios (> 5 filas)", true)
// )
